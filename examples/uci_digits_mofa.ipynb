# %%
from adnmtf import NMF, NTF
import pandas as pd
import numpy as np
from IPython.display import clear_output
import time
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import matplotlib.image as image
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import distinctipy
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

import sys
import networkx as nx

from sklearn.preprocessing import normalize
from sklearn import metrics

from mvlearn.datasets import load_UCImultifeature
from mvlearn.embed import MVMDS
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.cluster import KMeans
import umap
from scipy.spatial import distance_matrix
import hoggorm as ho
import adilsm.adilsm as ilsm

from sklearn.preprocessing import StandardScaler
from sklearn.metrics.cluster import rand_score

from mofapy2.run.entry_point import entry_point

# %% [markdown]
# Data prep

# %%
###############################################################################
# Load Data
# ---------
# Data comes from UCI Digits Data. Contains 6 views and classifications of
# numbers 0-9

Xs, list_digits = load_UCImultifeature()

sample_rate = 1

if sample_rate < 1:
    num_rows = list_digits.shape[0]
    num_rows_to_select = int(num_rows * sample_rate)
    selected_rows = np.random.choice(num_rows, num_rows_to_select, replace=False)

    for i in range(len(Xs)):
        Xs[i] = Xs[i][selected_rows]

    list_digits = list_digits[selected_rows]

list_cell_codes, list_cell_types = pd.factorize(list_digits)

# Check data
print(f'There are {len(Xs)} views.')
print(f'There are {Xs[0].shape[0]} observations')
print(f'The feature sizes are: {[X.shape[1] for X in Xs]}')
# Out:
# There are 6 views.
# There are 2000 observations
# The feature sizes are: [76, 216, 64, 240, 47, 6]

# %%
Xs_norm = Xs.copy()
scaler = StandardScaler()
for i in range(len(Xs)):
    Xs_norm[i] = Xs[i] - np.mean(Xs[i], axis=0)
    Xs_norm[i] = scaler.fit_transform(Xs_norm[i])

data_mat = [[None for g in range(1)] for m in range(6)]

for m in range(6):
    data_mat[m][0] = Xs_norm[m]

# %%
ent = entry_point()
ent.set_data_matrix(data_mat, likelihoods = ["gaussian" for _ in range(6)])
ent.set_model_options(
    factors = 10, 
    spikeslab_weights = False, 
    ard_weights = True
)
ent.set_train_options(
    convergence_mode = "medium", 
    dropR2 = 0.001, 
    gpu_mode = False, 
    seed = 1
)
ent.build()
ent.run()
factors = ent.model.nodes["Z"].getExpectation()
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=2000 samples and D=76 features...
# Successfully loaded view='view1' group='group0' with N=2000 samples and D=216 features...
# Successfully loaded view='view2' group='group0' with N=2000 samples and D=64 features...
# Successfully loaded view='view3' group='group0' with N=2000 samples and D=240 features...
# Successfully loaded view='view4' group='group0' with N=2000 samples and D=47 features...
# Successfully loaded view='view5' group='group0' with N=2000 samples and D=6 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
# - View 4 (view4): gaussian
# - View 5 (view5): gaussian
#
#
#
# Warning: some view(s) have less than 15 features, MOFA won't be able to learn meaningful factors for these view(s)...
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -9709296.32
#
# Iteration 1: time=0.37, ELBO=-1404936.80, deltaELBO=8304359.518 (85.52998325%), Factors=9
# Iteration 2: time=0.35, ELBO=-1304107.77, deltaELBO=100829.032 (1.03847930%), Factors=9
# Iteration 3: time=0.33, ELBO=-1292170.50, deltaELBO=11937.273 (0.12294684%), Factors=9
# Iteration 4: time=0.35, ELBO=-1285195.38, deltaELBO=6975.120 (0.07183961%), Factors=9
# Iteration 5: time=0.33, ELBO=-1279820.72, deltaELBO=5374.658 (0.05535579%), Factors=9
# Iteration 6: time=0.33, ELBO=-1274512.59, deltaELBO=5308.129 (0.05467058%), Factors=9
# Iteration 7: time=0.33, ELBO=-1268085.65, deltaELBO=6426.940 (0.06619368%), Factors=9
# Iteration 8: time=0.33, ELBO=-1260996.51, deltaELBO=7089.137 (0.07301392%), Factors=9
# Iteration 9: time=0.33, ELBO=-1255267.26, deltaELBO=5729.254 (0.05900792%), Factors=9
# Iteration 10: time=0.33, ELBO=-1251797.77, deltaELBO=3469.488 (0.03573367%), Factors=9
# Iteration 11: time=0.35, ELBO=-1249936.84, deltaELBO=1860.927 (0.01916645%), Factors=9
# Iteration 12: time=0.39, ELBO=-1248892.38, deltaELBO=1044.460 (0.01075732%), Factors=9
# Iteration 13: time=0.82, ELBO=-1248210.98, deltaELBO=681.405 (0.00701807%), Factors=9
# Iteration 14: time=0.43, ELBO=-1247693.58, deltaELBO=517.396 (0.00532887%), Factors=9
# Iteration 15: time=0.43, ELBO=-1247260.66, deltaELBO=432.928 (0.00445890%), Factors=9
# Iteration 16: time=0.42, ELBO=-1246878.89, deltaELBO=381.764 (0.00393194%), Factors=9
# Iteration 17: time=0.37, ELBO=-1246532.61, deltaELBO=346.282 (0.00356650%), Factors=9
# Iteration 18: time=0.37, ELBO=-1246213.39, deltaELBO=319.223 (0.00328781%), Factors=9
# Iteration 19: time=0.44, ELBO=-1245916.12, deltaELBO=297.270 (0.00306170%), Factors=9
# Iteration 20: time=0.45, ELBO=-1245637.38, deltaELBO=278.732 (0.00287078%), Factors=9
# Iteration 21: time=0.45, ELBO=-1245374.72, deltaELBO=262.661 (0.00270525%), Factors=9
# Iteration 22: time=0.47, ELBO=-1245126.25, deltaELBO=248.476 (0.00255915%), Factors=9
# Iteration 23: time=0.63, ELBO=-1244890.45, deltaELBO=235.793 (0.00242853%), Factors=9
# Iteration 24: time=0.48, ELBO=-1244666.11, deltaELBO=224.346 (0.00231063%), Factors=9
# Iteration 25: time=0.43, ELBO=-1244452.17, deltaELBO=213.937 (0.00220343%), Factors=9
# Iteration 26: time=0.50, ELBO=-1244247.75, deltaELBO=204.419 (0.00210539%), Factors=9
# Iteration 27: time=0.45, ELBO=-1244052.08, deltaELBO=195.672 (0.00201531%), Factors=9
# Iteration 28: time=0.45, ELBO=-1243864.48, deltaELBO=187.602 (0.00193219%), Factors=9
# Iteration 29: time=0.37, ELBO=-1243684.35, deltaELBO=180.131 (0.00185524%), Factors=9
# Iteration 30: time=0.38, ELBO=-1243511.16, deltaELBO=173.192 (0.00178378%), Factors=9
# Iteration 31: time=0.37, ELBO=-1243344.43, deltaELBO=166.729 (0.00171721%), Factors=9
# Iteration 32: time=0.37, ELBO=-1243183.73, deltaELBO=160.695 (0.00165506%), Factors=9
# Iteration 33: time=0.38, ELBO=-1243028.69, deltaELBO=155.046 (0.00159688%), Factors=9
# Iteration 34: time=0.38, ELBO=-1242878.94, deltaELBO=149.746 (0.00154229%), Factors=9
# Iteration 35: time=0.37, ELBO=-1242734.18, deltaELBO=144.762 (0.00149096%), Factors=9
# Iteration 36: time=0.37, ELBO=-1242594.11, deltaELBO=140.066 (0.00144260%), Factors=9
# Iteration 37: time=0.38, ELBO=-1242458.48, deltaELBO=135.633 (0.00139694%), Factors=9
# Iteration 38: time=0.37, ELBO=-1242327.04, deltaELBO=131.439 (0.00135374%), Factors=9
# Iteration 39: time=0.38, ELBO=-1242199.58, deltaELBO=127.464 (0.00131281%), Factors=9
# Iteration 40: time=0.37, ELBO=-1242075.89, deltaELBO=123.690 (0.00127393%), Factors=9
# Iteration 41: time=0.37, ELBO=-1241955.78, deltaELBO=120.100 (0.00123696%), Factors=9
# Iteration 42: time=0.38, ELBO=-1241839.11, deltaELBO=116.680 (0.00120173%), Factors=9
# Iteration 43: time=0.38, ELBO=-1241725.69, deltaELBO=113.415 (0.00116811%), Factors=9
# Iteration 44: time=0.37, ELBO=-1241615.39, deltaELBO=110.295 (0.00113597%), Factors=9
# Iteration 45: time=0.37, ELBO=-1241508.09, deltaELBO=107.307 (0.00110520%), Factors=9
# Iteration 46: time=0.37, ELBO=-1241403.64, deltaELBO=104.443 (0.00107570%), Factors=9
# Iteration 47: time=0.39, ELBO=-1241301.95, deltaELBO=101.692 (0.00104737%), Factors=9
# Iteration 48: time=0.38, ELBO=-1241202.90, deltaELBO=99.048 (0.00102013%), Factors=9
# Iteration 49: time=0.38, ELBO=-1241106.40, deltaELBO=96.502 (0.00099391%), Factors=9
# Iteration 50: time=0.36, ELBO=-1241012.35, deltaELBO=94.049 (0.00096864%), Factors=9
# Iteration 51: time=0.40, ELBO=-1240920.67, deltaELBO=91.681 (0.00094426%), Factors=9
# Iteration 52: time=0.38, ELBO=-1240831.28, deltaELBO=89.395 (0.00092072%), Factors=9
# Iteration 53: time=0.37, ELBO=-1240744.09, deltaELBO=87.185 (0.00089795%), Factors=9
# Iteration 54: time=0.37, ELBO=-1240659.05, deltaELBO=85.047 (0.00087593%), Factors=9
# Iteration 55: time=0.38, ELBO=-1240576.07, deltaELBO=82.977 (0.00085462%), Factors=9
# Iteration 56: time=0.37, ELBO=-1240495.10, deltaELBO=80.973 (0.00083397%), Factors=9
# Iteration 57: time=0.44, ELBO=-1240416.07, deltaELBO=79.030 (0.00081396%), Factors=9
# Iteration 58: time=0.42, ELBO=-1240338.92, deltaELBO=77.147 (0.00079457%), Factors=9
# Iteration 59: time=0.37, ELBO=-1240263.60, deltaELBO=75.321 (0.00077576%), Factors=9
# Iteration 60: time=0.40, ELBO=-1240190.05, deltaELBO=73.550 (0.00075752%), Factors=9
# Iteration 61: time=0.37, ELBO=-1240118.22, deltaELBO=71.832 (0.00073983%), Factors=9
# Iteration 62: time=0.37, ELBO=-1240048.05, deltaELBO=70.166 (0.00072267%), Factors=9
# Iteration 63: time=0.37, ELBO=-1239979.50, deltaELBO=68.550 (0.00070603%), Factors=9
# Iteration 64: time=0.37, ELBO=-1239912.52, deltaELBO=66.984 (0.00068989%), Factors=9
# Iteration 65: time=0.37, ELBO=-1239847.05, deltaELBO=65.465 (0.00067425%), Factors=9
# Iteration 66: time=0.40, ELBO=-1239783.06, deltaELBO=63.992 (0.00065908%), Factors=9
# Iteration 67: time=0.39, ELBO=-1239720.50, deltaELBO=62.565 (0.00064438%), Factors=9
# Iteration 68: time=0.77, ELBO=-1239659.31, deltaELBO=61.183 (0.00063014%), Factors=9
# Iteration 69: time=0.41, ELBO=-1239599.47, deltaELBO=59.843 (0.00061635%), Factors=9
# Iteration 70: time=0.47, ELBO=-1239540.92, deltaELBO=58.547 (0.00060300%), Factors=9
# Iteration 71: time=0.38, ELBO=-1239483.63, deltaELBO=57.291 (0.00059007%), Factors=9
# Iteration 72: time=0.37, ELBO=-1239427.55, deltaELBO=56.077 (0.00057756%), Factors=9
# Iteration 73: time=0.37, ELBO=-1239372.65, deltaELBO=54.901 (0.00056545%), Factors=9
# Iteration 74: time=0.37, ELBO=-1239318.89, deltaELBO=53.764 (0.00055374%), Factors=9
# Iteration 75: time=0.38, ELBO=-1239266.23, deltaELBO=52.664 (0.00054241%), Factors=9
# Iteration 76: time=0.34, ELBO=-1239214.62, deltaELBO=51.601 (0.00053146%), Factors=9
# Iteration 77: time=0.38, ELBO=-1239164.05, deltaELBO=50.572 (0.00052086%), Factors=9
# Iteration 78: time=0.38, ELBO=-1239114.47, deltaELBO=49.578 (0.00051062%), Factors=9
# Iteration 79: time=0.37, ELBO=-1239065.86, deltaELBO=48.616 (0.00050072%), Factors=9
# Iteration 80: time=0.38, ELBO=-1239018.17, deltaELBO=47.686 (0.00049114%), Factors=9
# Iteration 81: time=0.38, ELBO=-1238971.39, deltaELBO=46.787 (0.00048188%), Factors=9
# Iteration 82: time=0.37, ELBO=-1238925.47, deltaELBO=45.918 (0.00047293%), Factors=9
# Iteration 83: time=0.37, ELBO=-1238880.39, deltaELBO=45.077 (0.00046426%), Factors=9
# Iteration 84: time=0.38, ELBO=-1238836.13, deltaELBO=44.263 (0.00045588%), Factors=9
# Iteration 85: time=0.38, ELBO=-1238792.65, deltaELBO=43.476 (0.00044777%), Factors=9
# Iteration 86: time=0.37, ELBO=-1238749.94, deltaELBO=42.713 (0.00043992%), Factors=9
# Iteration 87: time=0.41, ELBO=-1238707.96, deltaELBO=41.975 (0.00043232%), Factors=9
# Iteration 88: time=0.42, ELBO=-1238666.70, deltaELBO=41.261 (0.00042496%), Factors=9
# Iteration 89: time=0.38, ELBO=-1238626.14, deltaELBO=40.568 (0.00041783%), Factors=9
# Iteration 90: time=0.35, ELBO=-1238586.24, deltaELBO=39.897 (0.00041091%), Factors=9
# Iteration 91: time=0.37, ELBO=-1238546.99, deltaELBO=39.246 (0.00040421%), Factors=9
# Iteration 92: time=0.35, ELBO=-1238508.38, deltaELBO=38.614 (0.00039771%), Factors=9
# Iteration 93: time=0.37, ELBO=-1238470.38, deltaELBO=38.002 (0.00039139%), Factors=9
# Iteration 94: time=0.36, ELBO=-1238432.97, deltaELBO=37.407 (0.00038527%), Factors=9
# Iteration 95: time=0.35, ELBO=-1238396.14, deltaELBO=36.829 (0.00037931%), Factors=9
# Iteration 96: time=0.35, ELBO=-1238359.87, deltaELBO=36.267 (0.00037353%), Factors=9
# Iteration 97: time=0.38, ELBO=-1238324.15, deltaELBO=35.721 (0.00036791%), Factors=9
# Iteration 98: time=0.38, ELBO=-1238288.96, deltaELBO=35.190 (0.00036244%), Factors=9
# Iteration 99: time=0.38, ELBO=-1238254.29, deltaELBO=34.674 (0.00035712%), Factors=9
# Iteration 100: time=0.38, ELBO=-1238220.12, deltaELBO=34.171 (0.00035194%), Factors=9
# Iteration 101: time=0.38, ELBO=-1238186.44, deltaELBO=33.681 (0.00034689%), Factors=9
# Iteration 102: time=0.37, ELBO=-1238153.23, deltaELBO=33.203 (0.00034198%), Factors=9
# Iteration 103: time=0.36, ELBO=-1238120.50, deltaELBO=32.738 (0.00033718%), Factors=9
# Iteration 104: time=0.37, ELBO=-1238088.21, deltaELBO=32.284 (0.00033251%), Factors=9
# Iteration 105: time=0.37, ELBO=-1238056.37, deltaELBO=31.842 (0.00032795%), Factors=9
# Iteration 106: time=0.36, ELBO=-1238024.96, deltaELBO=31.410 (0.00032350%), Factors=9
# Iteration 107: time=0.38, ELBO=-1237993.97, deltaELBO=30.988 (0.00031916%), Factors=9
# Iteration 108: time=0.38, ELBO=-1237963.40, deltaELBO=30.577 (0.00031492%), Factors=9
# Iteration 109: time=0.38, ELBO=-1237933.22, deltaELBO=30.174 (0.00031078%), Factors=9
# Iteration 110: time=0.37, ELBO=-1237903.44, deltaELBO=29.781 (0.00030673%), Factors=9
# Iteration 111: time=0.39, ELBO=-1237874.04, deltaELBO=29.397 (0.00030277%), Factors=9
# Iteration 112: time=0.36, ELBO=-1237845.02, deltaELBO=29.021 (0.00029890%), Factors=9
# Iteration 113: time=0.44, ELBO=-1237816.37, deltaELBO=28.653 (0.00029511%), Factors=9
# Iteration 114: time=0.41, ELBO=-1237788.08, deltaELBO=28.293 (0.00029140%), Factors=9
# Iteration 115: time=0.40, ELBO=-1237760.14, deltaELBO=27.941 (0.00028777%), Factors=9
# Iteration 116: time=0.45, ELBO=-1237732.54, deltaELBO=27.596 (0.00028422%), Factors=9
# Iteration 117: time=0.38, ELBO=-1237705.28, deltaELBO=27.258 (0.00028074%), Factors=9
# Iteration 118: time=0.38, ELBO=-1237678.35, deltaELBO=26.927 (0.00027733%), Factors=9
# Iteration 119: time=0.45, ELBO=-1237651.75, deltaELBO=26.603 (0.00027400%), Factors=9
# Iteration 120: time=0.36, ELBO=-1237625.47, deltaELBO=26.285 (0.00027072%), Factors=9
# Iteration 121: time=0.38, ELBO=-1237599.49, deltaELBO=25.974 (0.00026751%), Factors=9
# Iteration 122: time=0.37, ELBO=-1237573.82, deltaELBO=25.668 (0.00026437%), Factors=9
# Iteration 123: time=0.37, ELBO=-1237548.46, deltaELBO=25.369 (0.00026128%), Factors=9
# Iteration 124: time=0.38, ELBO=-1237523.38, deltaELBO=25.075 (0.00025826%), Factors=9
# Iteration 125: time=0.38, ELBO=-1237498.59, deltaELBO=24.787 (0.00025529%), Factors=9
# Iteration 126: time=0.35, ELBO=-1237474.09, deltaELBO=24.504 (0.00025238%), Factors=9
# Iteration 127: time=0.35, ELBO=-1237449.86, deltaELBO=24.226 (0.00024952%), Factors=9
# Iteration 128: time=0.37, ELBO=-1237425.91, deltaELBO=23.954 (0.00024671%), Factors=9
# Iteration 129: time=0.40, ELBO=-1237402.22, deltaELBO=23.686 (0.00024395%), Factors=9
# Iteration 130: time=0.35, ELBO=-1237378.80, deltaELBO=23.423 (0.00024125%), Factors=9
# Iteration 131: time=0.38, ELBO=-1237355.63, deltaELBO=23.165 (0.00023859%), Factors=9
# Iteration 132: time=0.37, ELBO=-1237332.72, deltaELBO=22.912 (0.00023598%), Factors=9
# Iteration 133: time=0.36, ELBO=-1237310.06, deltaELBO=22.663 (0.00023341%), Factors=9
# Iteration 134: time=0.34, ELBO=-1237287.64, deltaELBO=22.418 (0.00023089%), Factors=9
# Iteration 135: time=0.40, ELBO=-1237265.46, deltaELBO=22.178 (0.00022842%), Factors=9
# Iteration 136: time=0.37, ELBO=-1237243.52, deltaELBO=21.942 (0.00022598%), Factors=9
# Iteration 137: time=0.38, ELBO=-1237221.81, deltaELBO=21.709 (0.00022359%), Factors=9
# Iteration 138: time=0.37, ELBO=-1237200.33, deltaELBO=21.481 (0.00022124%), Factors=9
# Iteration 139: time=0.77, ELBO=-1237179.08, deltaELBO=21.257 (0.00021893%), Factors=9
# Iteration 140: time=0.41, ELBO=-1237158.04, deltaELBO=21.036 (0.00021666%), Factors=9
# Iteration 141: time=0.43, ELBO=-1237137.22, deltaELBO=20.819 (0.00021442%), Factors=9
# Iteration 142: time=0.37, ELBO=-1237116.62, deltaELBO=20.605 (0.00021222%), Factors=9
# Iteration 143: time=0.37, ELBO=-1237096.22, deltaELBO=20.395 (0.00021006%), Factors=9
# Iteration 144: time=0.35, ELBO=-1237076.03, deltaELBO=20.189 (0.00020793%), Factors=9
# Iteration 145: time=0.38, ELBO=-1237056.05, deltaELBO=19.986 (0.00020584%), Factors=9
# Iteration 146: time=0.35, ELBO=-1237036.26, deltaELBO=19.786 (0.00020378%), Factors=9
# Iteration 147: time=0.40, ELBO=-1237016.67, deltaELBO=19.589 (0.00020176%), Factors=9
# Iteration 148: time=0.36, ELBO=-1236997.28, deltaELBO=19.396 (0.00019976%), Factors=9
# Iteration 149: time=0.38, ELBO=-1236978.07, deltaELBO=19.205 (0.00019780%), Factors=9
# Iteration 150: time=0.34, ELBO=-1236959.05, deltaELBO=19.017 (0.00019587%), Factors=9
# Iteration 151: time=0.38, ELBO=-1236940.22, deltaELBO=18.833 (0.00019397%), Factors=9
# Iteration 152: time=0.35, ELBO=-1236921.57, deltaELBO=18.651 (0.00019210%), Factors=9
# Iteration 153: time=0.38, ELBO=-1236903.10, deltaELBO=18.472 (0.00019025%), Factors=9
# Iteration 154: time=0.35, ELBO=-1236884.80, deltaELBO=18.296 (0.00018844%), Factors=9
# Iteration 155: time=0.37, ELBO=-1236866.68, deltaELBO=18.123 (0.00018665%), Factors=9
# Iteration 156: time=0.37, ELBO=-1236848.73, deltaELBO=17.952 (0.00018490%), Factors=9
# Iteration 157: time=0.38, ELBO=-1236830.94, deltaELBO=17.784 (0.00018316%), Factors=9
# Iteration 158: time=0.38, ELBO=-1236813.32, deltaELBO=17.618 (0.00018146%), Factors=9
# Iteration 159: time=0.39, ELBO=-1236795.87, deltaELBO=17.455 (0.00017978%), Factors=9
# Iteration 160: time=0.36, ELBO=-1236778.57, deltaELBO=17.294 (0.00017812%), Factors=9
# Iteration 161: time=0.40, ELBO=-1236761.44, deltaELBO=17.136 (0.00017649%), Factors=9
# Iteration 162: time=0.36, ELBO=-1236744.46, deltaELBO=16.980 (0.00017488%), Factors=9
# Iteration 163: time=0.37, ELBO=-1236727.63, deltaELBO=16.826 (0.00017330%), Factors=9
# Iteration 164: time=0.34, ELBO=-1236710.96, deltaELBO=16.675 (0.00017174%), Factors=9
# Iteration 165: time=0.37, ELBO=-1236694.43, deltaELBO=16.526 (0.00017021%), Factors=9
# Iteration 166: time=0.35, ELBO=-1236678.05, deltaELBO=16.379 (0.00016869%), Factors=9
# Iteration 167: time=0.42, ELBO=-1236661.82, deltaELBO=16.234 (0.00016720%), Factors=9
# Iteration 168: time=0.36, ELBO=-1236645.73, deltaELBO=16.091 (0.00016573%), Factors=9
# Iteration 169: time=0.38, ELBO=-1236629.78, deltaELBO=15.950 (0.00016428%), Factors=9
# Iteration 170: time=0.40, ELBO=-1236613.97, deltaELBO=15.811 (0.00016285%), Factors=9
# Iteration 171: time=0.42, ELBO=-1236598.29, deltaELBO=15.675 (0.00016144%), Factors=9
# Iteration 172: time=0.40, ELBO=-1236582.75, deltaELBO=15.540 (0.00016005%), Factors=9
# Iteration 173: time=0.37, ELBO=-1236567.35, deltaELBO=15.407 (0.00015868%), Factors=9
# Iteration 174: time=0.37, ELBO=-1236552.07, deltaELBO=15.276 (0.00015733%), Factors=9
# Iteration 175: time=0.38, ELBO=-1236536.92, deltaELBO=15.146 (0.00015600%), Factors=9
# Iteration 176: time=0.35, ELBO=-1236521.90, deltaELBO=15.019 (0.00015469%), Factors=9
# Iteration 177: time=0.37, ELBO=-1236507.01, deltaELBO=14.893 (0.00015339%), Factors=9
# Iteration 178: time=0.40, ELBO=-1236492.24, deltaELBO=14.769 (0.00015211%), Factors=9
# Iteration 179: time=0.54, ELBO=-1236477.59, deltaELBO=14.647 (0.00015086%), Factors=9
# Iteration 180: time=0.49, ELBO=-1236463.07, deltaELBO=14.526 (0.00014961%), Factors=9
# Iteration 181: time=0.47, ELBO=-1236448.66, deltaELBO=14.407 (0.00014839%), Factors=9
# Iteration 182: time=0.40, ELBO=-1236434.37, deltaELBO=14.290 (0.00014718%), Factors=9
# Iteration 183: time=0.72, ELBO=-1236420.20, deltaELBO=14.174 (0.00014599%), Factors=9
# Iteration 184: time=0.73, ELBO=-1236406.14, deltaELBO=14.060 (0.00014481%), Factors=9
# Iteration 185: time=0.67, ELBO=-1236392.19, deltaELBO=13.947 (0.00014365%), Factors=9
# Iteration 186: time=0.41, ELBO=-1236378.35, deltaELBO=13.836 (0.00014251%), Factors=9
# Iteration 187: time=0.54, ELBO=-1236364.63, deltaELBO=13.727 (0.00014138%), Factors=9
# Iteration 188: time=0.62, ELBO=-1236351.01, deltaELBO=13.618 (0.00014026%), Factors=9
# Iteration 189: time=0.62, ELBO=-1236337.50, deltaELBO=13.511 (0.00013916%), Factors=9
# Iteration 190: time=0.37, ELBO=-1236324.09, deltaELBO=13.406 (0.00013807%), Factors=9
# Iteration 191: time=0.48, ELBO=-1236310.79, deltaELBO=13.302 (0.00013700%), Factors=9
# Iteration 192: time=0.31, ELBO=-1236297.59, deltaELBO=13.199 (0.00013594%), Factors=9
# Iteration 193: time=0.32, ELBO=-1236284.49, deltaELBO=13.098 (0.00013490%), Factors=9
# Iteration 194: time=0.31, ELBO=-1236271.49, deltaELBO=12.998 (0.00013387%), Factors=9
# Iteration 195: time=0.31, ELBO=-1236258.59, deltaELBO=12.899 (0.00013285%), Factors=9
# Iteration 196: time=0.32, ELBO=-1236245.79, deltaELBO=12.802 (0.00013185%), Factors=9
# Iteration 197: time=0.32, ELBO=-1236233.09, deltaELBO=12.705 (0.00013086%), Factors=9
# Iteration 198: time=0.30, ELBO=-1236220.48, deltaELBO=12.610 (0.00012988%), Factors=9
# Iteration 199: time=0.33, ELBO=-1236207.96, deltaELBO=12.516 (0.00012891%), Factors=9
# Iteration 200: time=0.31, ELBO=-1236195.54, deltaELBO=12.424 (0.00012796%), Factors=9
# Iteration 201: time=0.32, ELBO=-1236183.20, deltaELBO=12.332 (0.00012701%), Factors=9
# Iteration 202: time=0.49, ELBO=-1236170.96, deltaELBO=12.242 (0.00012608%), Factors=9
# Iteration 203: time=0.31, ELBO=-1236158.81, deltaELBO=12.153 (0.00012516%), Factors=9
# Iteration 204: time=0.33, ELBO=-1236146.75, deltaELBO=12.064 (0.00012426%), Factors=9
# Iteration 205: time=0.32, ELBO=-1236134.77, deltaELBO=11.977 (0.00012336%), Factors=9
# Iteration 206: time=0.30, ELBO=-1236122.88, deltaELBO=11.891 (0.00012247%), Factors=9
# Iteration 207: time=0.33, ELBO=-1236111.07, deltaELBO=11.806 (0.00012160%), Factors=9
# Iteration 208: time=0.33, ELBO=-1236099.35, deltaELBO=11.723 (0.00012074%), Factors=9
# Iteration 209: time=0.33, ELBO=-1236087.71, deltaELBO=11.640 (0.00011988%), Factors=9
# Iteration 210: time=0.32, ELBO=-1236076.15, deltaELBO=11.558 (0.00011904%), Factors=9
# Iteration 211: time=0.33, ELBO=-1236064.67, deltaELBO=11.477 (0.00011821%), Factors=9
# Iteration 212: time=0.31, ELBO=-1236053.28, deltaELBO=11.397 (0.00011738%), Factors=9
# Iteration 213: time=0.32, ELBO=-1236041.96, deltaELBO=11.318 (0.00011657%), Factors=9
# Iteration 214: time=0.33, ELBO=-1236030.72, deltaELBO=11.240 (0.00011576%), Factors=9
# Iteration 215: time=0.36, ELBO=-1236019.56, deltaELBO=11.163 (0.00011497%), Factors=9
# Iteration 216: time=0.31, ELBO=-1236008.47, deltaELBO=11.087 (0.00011419%), Factors=9
# Iteration 217: time=0.32, ELBO=-1235997.46, deltaELBO=11.011 (0.00011341%), Factors=9
# Iteration 218: time=0.36, ELBO=-1235986.52, deltaELBO=10.937 (0.00011264%), Factors=9
# Iteration 219: time=0.33, ELBO=-1235975.66, deltaELBO=10.863 (0.00011188%), Factors=9
# Iteration 220: time=0.37, ELBO=-1235964.87, deltaELBO=10.790 (0.00011114%), Factors=9
# Iteration 221: time=0.42, ELBO=-1235954.15, deltaELBO=10.719 (0.00011039%), Factors=9
# Iteration 222: time=0.34, ELBO=-1235943.50, deltaELBO=10.647 (0.00010966%), Factors=9
# Iteration 223: time=0.33, ELBO=-1235932.92, deltaELBO=10.577 (0.00010894%), Factors=9
# Iteration 224: time=0.32, ELBO=-1235922.42, deltaELBO=10.508 (0.00010822%), Factors=9
# Iteration 225: time=0.35, ELBO=-1235911.98, deltaELBO=10.439 (0.00010752%), Factors=9
# Iteration 226: time=0.35, ELBO=-1235901.61, deltaELBO=10.371 (0.00010682%), Factors=9
# Iteration 227: time=0.32, ELBO=-1235891.30, deltaELBO=10.304 (0.00010613%), Factors=9
# Iteration 228: time=0.30, ELBO=-1235881.06, deltaELBO=10.238 (0.00010544%), Factors=9
# Iteration 229: time=0.37, ELBO=-1235870.89, deltaELBO=10.172 (0.00010477%), Factors=9
# Iteration 230: time=0.35, ELBO=-1235860.79, deltaELBO=10.107 (0.00010410%), Factors=9
# Iteration 231: time=0.39, ELBO=-1235850.74, deltaELBO=10.043 (0.00010344%), Factors=9
# Iteration 232: time=0.38, ELBO=-1235840.76, deltaELBO=9.979 (0.00010278%), Factors=9
# Iteration 233: time=0.33, ELBO=-1235830.85, deltaELBO=9.917 (0.00010213%), Factors=9
# Iteration 234: time=0.29, ELBO=-1235820.99, deltaELBO=9.854 (0.00010149%), Factors=9
# Iteration 235: time=0.37, ELBO=-1235811.20, deltaELBO=9.793 (0.00010086%), Factors=9
# Iteration 236: time=0.33, ELBO=-1235801.47, deltaELBO=9.732 (0.00010024%), Factors=9
# Iteration 237: time=0.31, ELBO=-1235791.80, deltaELBO=9.672 (0.00009962%), Factors=9
# Iteration 238: time=0.36, ELBO=-1235782.18, deltaELBO=9.613 (0.00009900%), Factors=9
# Iteration 239: time=0.32, ELBO=-1235772.63, deltaELBO=9.554 (0.00009840%), Factors=9
# Iteration 240: time=0.35, ELBO=-1235763.13, deltaELBO=9.495 (0.00009780%), Factors=9
# Iteration 241: time=0.37, ELBO=-1235753.70, deltaELBO=9.438 (0.00009720%), Factors=9
# Iteration 242: time=0.33, ELBO=-1235744.32, deltaELBO=9.381 (0.00009662%), Factors=9
# Iteration 243: time=0.32, ELBO=-1235734.99, deltaELBO=9.324 (0.00009604%), Factors=9
# Iteration 244: time=0.32, ELBO=-1235725.72, deltaELBO=9.269 (0.00009546%), Factors=9
# Iteration 245: time=0.33, ELBO=-1235716.51, deltaELBO=9.213 (0.00009489%), Factors=9
# Iteration 246: time=0.32, ELBO=-1235707.35, deltaELBO=9.159 (0.00009433%), Factors=9
# Iteration 247: time=0.43, ELBO=-1235698.25, deltaELBO=9.104 (0.00009377%), Factors=9
# Iteration 248: time=0.53, ELBO=-1235689.20, deltaELBO=9.051 (0.00009322%), Factors=9
# Iteration 249: time=0.54, ELBO=-1235680.20, deltaELBO=8.998 (0.00009267%), Factors=9
# Iteration 250: time=0.44, ELBO=-1235671.25, deltaELBO=8.945 (0.00009213%), Factors=9
# Iteration 251: time=0.57, ELBO=-1235662.36, deltaELBO=8.893 (0.00009160%), Factors=9
# Iteration 252: time=0.46, ELBO=-1235653.52, deltaELBO=8.842 (0.00009107%), Factors=9
# Iteration 253: time=0.41, ELBO=-1235644.73, deltaELBO=8.791 (0.00009054%), Factors=9
# Iteration 254: time=0.51, ELBO=-1235635.98, deltaELBO=8.741 (0.00009002%), Factors=9
# Iteration 255: time=0.60, ELBO=-1235627.29, deltaELBO=8.691 (0.00008951%), Factors=9
# Iteration 256: time=0.61, ELBO=-1235618.65, deltaELBO=8.641 (0.00008900%), Factors=9
# Iteration 257: time=0.83, ELBO=-1235610.06, deltaELBO=8.592 (0.00008850%), Factors=9
# Iteration 258: time=0.84, ELBO=-1235601.52, deltaELBO=8.544 (0.00008800%), Factors=9
# Iteration 259: time=0.85, ELBO=-1235593.02, deltaELBO=8.496 (0.00008750%), Factors=9
# Iteration 260: time=0.70, ELBO=-1235584.57, deltaELBO=8.448 (0.00008701%), Factors=9
# Iteration 261: time=0.66, ELBO=-1235576.17, deltaELBO=8.401 (0.00008653%), Factors=9
# Iteration 262: time=0.60, ELBO=-1235567.82, deltaELBO=8.355 (0.00008605%), Factors=9
# Iteration 263: time=0.48, ELBO=-1235559.51, deltaELBO=8.309 (0.00008557%), Factors=9
# Iteration 264: time=0.41, ELBO=-1235551.24, deltaELBO=8.263 (0.00008510%), Factors=9
# Iteration 265: time=0.42, ELBO=-1235543.03, deltaELBO=8.218 (0.00008464%), Factors=9
# Iteration 266: time=0.45, ELBO=-1235534.85, deltaELBO=8.173 (0.00008417%), Factors=9
# Iteration 267: time=0.53, ELBO=-1235526.73, deltaELBO=8.128 (0.00008372%), Factors=9
# Iteration 268: time=0.49, ELBO=-1235518.64, deltaELBO=8.084 (0.00008326%), Factors=9
# Iteration 269: time=0.49, ELBO=-1235510.60, deltaELBO=8.041 (0.00008281%), Factors=9
# Iteration 270: time=0.62, ELBO=-1235502.60, deltaELBO=7.997 (0.00008237%), Factors=9
# Iteration 271: time=0.81, ELBO=-1235494.65, deltaELBO=7.954 (0.00008193%), Factors=9
# Iteration 272: time=0.73, ELBO=-1235486.74, deltaELBO=7.912 (0.00008149%), Factors=9
# Iteration 273: time=0.89, ELBO=-1235478.87, deltaELBO=7.870 (0.00008106%), Factors=9
# Iteration 274: time=1.14, ELBO=-1235471.04, deltaELBO=7.828 (0.00008063%), Factors=9
# Iteration 275: time=0.67, ELBO=-1235463.25, deltaELBO=7.787 (0.00008020%), Factors=9
# Iteration 276: time=0.67, ELBO=-1235455.51, deltaELBO=7.746 (0.00007978%), Factors=9
# Iteration 277: time=0.65, ELBO=-1235447.80, deltaELBO=7.706 (0.00007936%), Factors=9
# Iteration 278: time=0.52, ELBO=-1235440.14, deltaELBO=7.665 (0.00007895%), Factors=9
# Iteration 279: time=0.51, ELBO=-1235432.51, deltaELBO=7.626 (0.00007854%), Factors=9
# Iteration 280: time=0.44, ELBO=-1235424.92, deltaELBO=7.586 (0.00007813%), Factors=9
# Iteration 281: time=0.55, ELBO=-1235417.38, deltaELBO=7.547 (0.00007773%), Factors=9
# Iteration 282: time=0.50, ELBO=-1235409.87, deltaELBO=7.508 (0.00007733%), Factors=9
# Iteration 283: time=0.55, ELBO=-1235402.40, deltaELBO=7.470 (0.00007693%), Factors=9
# Iteration 284: time=0.47, ELBO=-1235394.97, deltaELBO=7.432 (0.00007654%), Factors=9
# Iteration 285: time=0.83, ELBO=-1235387.57, deltaELBO=7.394 (0.00007615%), Factors=9
# Iteration 286: time=0.72, ELBO=-1235380.22, deltaELBO=7.356 (0.00007576%), Factors=9
# Iteration 287: time=0.60, ELBO=-1235372.90, deltaELBO=7.319 (0.00007538%), Factors=9
# Iteration 288: time=0.55, ELBO=-1235365.62, deltaELBO=7.282 (0.00007500%), Factors=9
# Iteration 289: time=0.47, ELBO=-1235358.37, deltaELBO=7.246 (0.00007463%), Factors=9
# Iteration 290: time=0.48, ELBO=-1235351.16, deltaELBO=7.209 (0.00007425%), Factors=9
# Iteration 291: time=0.50, ELBO=-1235343.99, deltaELBO=7.174 (0.00007388%), Factors=9
# Iteration 292: time=0.53, ELBO=-1235336.85, deltaELBO=7.138 (0.00007352%), Factors=9
# Iteration 293: time=0.67, ELBO=-1235329.75, deltaELBO=7.103 (0.00007315%), Factors=9
# Iteration 294: time=0.53, ELBO=-1235322.68, deltaELBO=7.068 (0.00007279%), Factors=9
# Iteration 295: time=0.50, ELBO=-1235315.65, deltaELBO=7.033 (0.00007243%), Factors=9
# Iteration 296: time=0.58, ELBO=-1235308.65, deltaELBO=6.998 (0.00007208%), Factors=9
# Iteration 297: time=0.79, ELBO=-1235301.68, deltaELBO=6.964 (0.00007173%), Factors=9
# Iteration 298: time=0.94, ELBO=-1235294.75, deltaELBO=6.930 (0.00007138%), Factors=9
# Iteration 299: time=1.00, ELBO=-1235287.86, deltaELBO=6.897 (0.00007103%), Factors=9
# Iteration 300: time=1.03, ELBO=-1235280.99, deltaELBO=6.863 (0.00007069%), Factors=9
# Iteration 301: time=1.14, ELBO=-1235274.16, deltaELBO=6.830 (0.00007035%), Factors=9
# Iteration 302: time=1.09, ELBO=-1235267.37, deltaELBO=6.797 (0.00007001%), Factors=9
# Iteration 303: time=0.99, ELBO=-1235260.60, deltaELBO=6.765 (0.00006967%), Factors=9
# Iteration 304: time=1.29, ELBO=-1235253.87, deltaELBO=6.732 (0.00006934%), Factors=9
# Iteration 305: time=0.91, ELBO=-1235247.17, deltaELBO=6.700 (0.00006901%), Factors=9
# Iteration 306: time=0.94, ELBO=-1235240.50, deltaELBO=6.669 (0.00006868%), Factors=9
# Iteration 307: time=1.22, ELBO=-1235233.86, deltaELBO=6.637 (0.00006836%), Factors=9
# Iteration 308: time=1.26, ELBO=-1235227.26, deltaELBO=6.606 (0.00006803%), Factors=9
# Iteration 309: time=1.17, ELBO=-1235220.68, deltaELBO=6.575 (0.00006771%), Factors=9
# Iteration 310: time=0.96, ELBO=-1235214.14, deltaELBO=6.544 (0.00006740%), Factors=9
# Iteration 311: time=0.86, ELBO=-1235207.63, deltaELBO=6.513 (0.00006708%), Factors=9
# Iteration 312: time=0.75, ELBO=-1235201.14, deltaELBO=6.483 (0.00006677%), Factors=9
# Iteration 313: time=0.83, ELBO=-1235194.69, deltaELBO=6.453 (0.00006646%), Factors=9
# Iteration 314: time=0.76, ELBO=-1235188.27, deltaELBO=6.423 (0.00006615%), Factors=9
# Iteration 315: time=0.65, ELBO=-1235181.87, deltaELBO=6.393 (0.00006584%), Factors=9
# Iteration 316: time=0.80, ELBO=-1235175.51, deltaELBO=6.364 (0.00006554%), Factors=9
# Iteration 317: time=0.74, ELBO=-1235169.18, deltaELBO=6.334 (0.00006524%), Factors=9
# Iteration 318: time=0.69, ELBO=-1235162.87, deltaELBO=6.305 (0.00006494%), Factors=9
# Iteration 319: time=0.95, ELBO=-1235156.60, deltaELBO=6.276 (0.00006464%), Factors=9
# Iteration 320: time=1.09, ELBO=-1235150.35, deltaELBO=6.248 (0.00006435%), Factors=9
# Iteration 321: time=0.96, ELBO=-1235144.13, deltaELBO=6.219 (0.00006406%), Factors=9
# Iteration 322: time=1.07, ELBO=-1235137.94, deltaELBO=6.191 (0.00006376%), Factors=9
# Iteration 323: time=0.88, ELBO=-1235131.77, deltaELBO=6.163 (0.00006348%), Factors=9
# Iteration 324: time=0.58, ELBO=-1235125.64, deltaELBO=6.135 (0.00006319%), Factors=9
# Iteration 325: time=0.62, ELBO=-1235119.53, deltaELBO=6.108 (0.00006291%), Factors=9
# Iteration 326: time=0.54, ELBO=-1235113.45, deltaELBO=6.080 (0.00006262%), Factors=9
# Iteration 327: time=0.70, ELBO=-1235107.40, deltaELBO=6.053 (0.00006234%), Factors=9
# Iteration 328: time=0.79, ELBO=-1235101.37, deltaELBO=6.026 (0.00006206%), Factors=9
# Iteration 329: time=0.61, ELBO=-1235095.37, deltaELBO=5.999 (0.00006179%), Factors=9
# Iteration 330: time=0.61, ELBO=-1235089.40, deltaELBO=5.973 (0.00006151%), Factors=9
# Iteration 331: time=0.60, ELBO=-1235083.45, deltaELBO=5.946 (0.00006124%), Factors=9
# Iteration 332: time=0.61, ELBO=-1235077.53, deltaELBO=5.920 (0.00006097%), Factors=9
# Iteration 333: time=0.62, ELBO=-1235071.64, deltaELBO=5.894 (0.00006070%), Factors=9
# Iteration 334: time=0.57, ELBO=-1235065.77, deltaELBO=5.868 (0.00006043%), Factors=9
# Iteration 335: time=0.64, ELBO=-1235059.93, deltaELBO=5.842 (0.00006017%), Factors=9
# Iteration 336: time=0.56, ELBO=-1235054.11, deltaELBO=5.816 (0.00005991%), Factors=9
# Iteration 337: time=0.55, ELBO=-1235048.32, deltaELBO=5.791 (0.00005964%), Factors=9
# Iteration 338: time=0.58, ELBO=-1235042.56, deltaELBO=5.766 (0.00005938%), Factors=9
# Iteration 339: time=0.60, ELBO=-1235036.82, deltaELBO=5.741 (0.00005913%), Factors=9
# Iteration 340: time=0.58, ELBO=-1235031.10, deltaELBO=5.716 (0.00005887%), Factors=9
# Iteration 341: time=0.70, ELBO=-1235025.41, deltaELBO=5.691 (0.00005861%), Factors=9
# Iteration 342: time=0.67, ELBO=-1235019.74, deltaELBO=5.667 (0.00005836%), Factors=9
# Iteration 343: time=0.80, ELBO=-1235014.10, deltaELBO=5.642 (0.00005811%), Factors=9
# Iteration 344: time=0.56, ELBO=-1235008.48, deltaELBO=5.618 (0.00005786%), Factors=9
# Iteration 345: time=0.69, ELBO=-1235002.89, deltaELBO=5.594 (0.00005761%), Factors=9
# Iteration 346: time=1.08, ELBO=-1234997.32, deltaELBO=5.570 (0.00005737%), Factors=9
# Iteration 347: time=0.62, ELBO=-1234991.77, deltaELBO=5.546 (0.00005712%), Factors=9
# Iteration 348: time=0.72, ELBO=-1234986.25, deltaELBO=5.522 (0.00005688%), Factors=9
# Iteration 349: time=0.63, ELBO=-1234980.75, deltaELBO=5.499 (0.00005664%), Factors=9
# Iteration 350: time=0.64, ELBO=-1234975.28, deltaELBO=5.476 (0.00005640%), Factors=9
# Iteration 351: time=0.59, ELBO=-1234969.82, deltaELBO=5.452 (0.00005616%), Factors=9
# Iteration 352: time=0.79, ELBO=-1234964.39, deltaELBO=5.429 (0.00005592%), Factors=9
# Iteration 353: time=1.11, ELBO=-1234958.99, deltaELBO=5.407 (0.00005568%), Factors=9
# Iteration 354: time=0.88, ELBO=-1234953.60, deltaELBO=5.384 (0.00005545%), Factors=9
# Iteration 355: time=0.87, ELBO=-1234948.24, deltaELBO=5.361 (0.00005522%), Factors=9
# Iteration 356: time=0.67, ELBO=-1234942.90, deltaELBO=5.339 (0.00005499%), Factors=9
# Iteration 357: time=0.92, ELBO=-1234937.59, deltaELBO=5.316 (0.00005476%), Factors=9
# Iteration 358: time=0.81, ELBO=-1234932.29, deltaELBO=5.294 (0.00005453%), Factors=9
# Iteration 359: time=0.72, ELBO=-1234927.02, deltaELBO=5.272 (0.00005430%), Factors=9
# Iteration 360: time=0.76, ELBO=-1234921.77, deltaELBO=5.250 (0.00005407%), Factors=9
# Iteration 361: time=0.77, ELBO=-1234916.54, deltaELBO=5.228 (0.00005385%), Factors=9
# Iteration 362: time=0.73, ELBO=-1234911.34, deltaELBO=5.207 (0.00005363%), Factors=9
# Iteration 363: time=0.86, ELBO=-1234906.15, deltaELBO=5.185 (0.00005341%), Factors=9
# Iteration 364: time=0.69, ELBO=-1234900.99, deltaELBO=5.164 (0.00005319%), Factors=9
# Iteration 365: time=0.96, ELBO=-1234895.84, deltaELBO=5.143 (0.00005297%), Factors=9
# Iteration 366: time=0.73, ELBO=-1234890.72, deltaELBO=5.122 (0.00005275%), Factors=9
# Iteration 367: time=0.82, ELBO=-1234885.62, deltaELBO=5.101 (0.00005253%), Factors=9
# Iteration 368: time=1.07, ELBO=-1234880.54, deltaELBO=5.080 (0.00005232%), Factors=9
# Iteration 369: time=1.01, ELBO=-1234875.48, deltaELBO=5.059 (0.00005210%), Factors=9
# Iteration 370: time=0.92, ELBO=-1234870.44, deltaELBO=5.038 (0.00005189%), Factors=9
# Iteration 371: time=0.89, ELBO=-1234865.43, deltaELBO=5.018 (0.00005168%), Factors=9
# Iteration 372: time=1.36, ELBO=-1234860.43, deltaELBO=4.997 (0.00005147%), Factors=9
# Iteration 373: time=1.64, ELBO=-1234855.45, deltaELBO=4.977 (0.00005126%), Factors=9
# Iteration 374: time=1.16, ELBO=-1234850.50, deltaELBO=4.957 (0.00005105%), Factors=9
# Iteration 375: time=1.11, ELBO=-1234845.56, deltaELBO=4.937 (0.00005085%), Factors=9
# Iteration 376: time=1.17, ELBO=-1234840.64, deltaELBO=4.917 (0.00005064%), Factors=9
# Iteration 377: time=1.31, ELBO=-1234835.74, deltaELBO=4.897 (0.00005044%), Factors=9
# Iteration 378: time=1.12, ELBO=-1234830.87, deltaELBO=4.877 (0.00005023%), Factors=9
# Iteration 379: time=1.01, ELBO=-1234826.01, deltaELBO=4.858 (0.00005003%), Factors=9
# Iteration 380: time=0.96, ELBO=-1234821.17, deltaELBO=4.838 (0.00004983%), Factors=9
# Iteration 381: time=1.36, ELBO=-1234816.35, deltaELBO=4.819 (0.00004963%), Factors=9
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################

# %% [markdown]
# Figures

# %%
# 16-16 with .8
# generate N visually distinct colours

# MDS projection
mds = MDS(n_components=2, random_state=0)
# mds = umap.UMAP(random_state=0, n_jobs=1, min_dist=1)

n_marker_genes = list_cell_codes.shape[0]

stress = []

w4_gfa = factors

w4_gfa_mds = mds.fit_transform(normalize(w4_gfa[:n_marker_genes,:], axis=0, norm='l2'))
stress.append(mds.stress_)

print(stress)
# Out:
# [1863.659405336067]

# %%
palette = distinctipy.get_colors(10)
cmap = ListedColormap(palette)

patches = []
for code in range(10):
    patches.append(mpatches.Patch(color=palette[code], label=list_cell_types[code]))

# Define a function to plot the confidence ellipse
def confidence_ellipse(x, y, cell_label, ax, n_std=2, facecolor='none', **kwargs):
    # Create a plot of the covariance confidence ellipse of `x` and `y`
    # Adapted from [1](https://matplotlib.org/stable/gallery/statistics/confidence_ellipse.html)
    
    # Calculate the covariance matrix and the Pearson correlation coefficient
    cov = np.cov(x, y)
    pearson = cov[0, 1] / np.sqrt(cov[0, 0] * cov[1, 1])
    
    # Use a special case to obtain the eigenvalues of the covariance matrix
    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    
    # Create the ellipse object
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)
    
    # Scale and translate the ellipse according to the mean and standard deviation of the data
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = np.mean(x)
    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = np.mean(y)
    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)
    ellipse.set_transform(transf + ax.transData)
    
    # Annotate centroid
    x_mean = np.mean(x)
    y_mean = np.mean(y)
    ax.annotate(int(cell_label), xy=(x_mean, y_mean))

    # Add the ellipse to the axes
    ax.add_patch(ellipse)
    return x_mean, y_mean

# define a function to plot scatter with clusters and confidence ellipses
def plot_scatter(x, y, title=None, k=None, ax=None, list_cell_codes=None, skip_ellipse=[], face_color='lavender', **kwargs):
    # Perform k-means clustering
    kmeans = KMeans(n_clusters=k, random_state=0).fit(np.c_[x, y])
    # Get the cluster labels and centroids
    labels = kmeans.labels_  # Get cluster labels
    labels_matched = np.empty_like(labels)
    unique_labels = np.unique(labels)
    truth_label = np.zeros(len(unique_labels))

    # For each cluster label...
    for l in unique_labels:
        # ...find and assign the best-matching truth label
        match_nums = [np.sum((labels==l)*(list_cell_codes==t)) for t in np.unique(list_cell_codes)]
        truth_label[l] = np.unique(list_cell_codes)[np.argmax(match_nums)]
        labels_matched[labels==l] = truth_label[l]

    ax.scatter(x, y, c=list_cell_codes[:n_marker_genes], cmap=cmap, alpha=0.5, s=20)
    ax.set_title(title)
    ax.set_xlabel("MDS-1")
    ax.set_ylabel("MDS-2")
    ax.set_facecolor(face_color)

    p1 = np.zeros(k)
    p2 = np.zeros(k)
    unique_labels_matched = np.unique(labels_matched)
    xy_mean = np.zeros((len(unique_labels),2))    
    mean_intra_distance = np.zeros(len(unique_labels))
    mean_inter_distance = np.zeros(len(unique_labels))
    flag = np.zeros(len(unique_labels))

    for l in unique_labels_matched:
        indices = np.where(truth_label == l)[0]
        if indices.shape[0] > 1:
            # calculate mean distance inter-clusters pointing to same class
            xy_mean2 = np.zeros((indices.shape[0],2))
            for l2 in range(len(indices)):
                xy_mean2[l2,0] = np.mean(x[labels == indices[l2]])
                xy_mean2[l2,1] = np.mean(y[labels == indices[l2]])
                xy_intra = np.column_stack((x[labels == indices[l2]], y[labels == indices[l2]]))
                D = distance_matrix(xy_intra, xy_intra)
                mean_intra_distance[l] += np.mean(D[D>0])
                    
            D = distance_matrix(xy_mean2, xy_mean2)
            mean_inter_distance[l] = np.mean(D[D>0])
            if mean_inter_distance[l] / mean_intra_distance[l] > 1:
                flag[l] = 1

    n_matched_cell_types = 0
    
    for l in np.unique(labels_matched):
        if not flag[l]:
            p1[l] = np.sum(labels_matched[labels_matched==l] == list_cell_codes[labels_matched==l])
            p2[l] = p1[l] / np.sum(list_cell_codes == l)
            p1[l] /=  np.sum(labels_matched == l)
            if p2[l] > .5:
                n_matched_cell_types += 1
                xy_mean[l,0], xy_mean[l,1] = confidence_ellipse(x[labels_matched == l], y[labels_matched == l], list_cell_types[l], ax, n_std=2, edgecolor='black')
            else:
                p1[l] = 0
                p2[l] = 0
        else:
            xy_mean[l,0] = 0
            xy_mean[l,1] = 0
    
    inter_distance = distance_matrix(xy_mean, xy_mean)
    mean_inter_distance = np.mean(inter_distance[inter_distance>0])
    norm_distance = np.max(inter_distance) - inter_distance
    # print(p1)
    # print(p2)
    print(n_matched_cell_types, round(np.sum(p1*p2),2))
    print(round(rand_score(labels_matched, list_cell_codes),4))

# fig, ax = plt.subplots(3, 2, figsize=(14, 18), constrained_layout=True)
fig, ax = plt.subplots(figsize=(8, 7), constrained_layout=True)

face_color = 'lavender'
k=10

plot_scatter(w4_gfa_mds[:, 0], w4_gfa_mds[:, 1], title="ISM Reduced Data (10-class)", k=k, ax=ax, list_cell_codes=list_cell_codes, skip_ellipse=[])

plt.show

# Add the legend to a new figure
fig2, ax2 = plt.subplots()
ax2.legend(handles=patches, loc='center')
plt.gca().set_axis_off()
ax2.set_facecolor(face_color)
plt.show
# Out:
# 7 2.91
# 0.867
# <function matplotlib.pyplot.show(close=None, block=None)>
