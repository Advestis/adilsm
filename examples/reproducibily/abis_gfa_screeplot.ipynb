# %%
from adnmtf import NMF, NTF
# from sklearn.decomposition import NMF
import pandas as pd
import numpy as np
from IPython.display import clear_output
import time
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import matplotlib.image as image
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import distinctipy
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

import sys
import networkx as nx
from sklearn.preprocessing import normalize
from sklearn import metrics

from mvlearn.datasets import load_UCImultifeature
from mvlearn.embed import MVMDS
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.cluster import KMeans
import umap
from scipy.spatial import distance_matrix
import hoggorm as ho
from sklearn.metrics.cluster import rand_score

import adilsm.adilsm as ilsm
import os

from sklearn.preprocessing import StandardScaler
from sklearn.metrics.cluster import rand_score

from gfa import gfa_experiments

RESULTS_PATH = '../results/'
DATA_PATH = '../data/'
# Out:
# adilsm version=0.0.13

# %% [markdown]
# Data prep

# %%
df = pd.read_csv(DATA_PATH + 'abis_915.csv', na_values=' ', index_col='gene_id')
# df = pd.read_csv(RESULTS_PATH + r'\abis_915_1000_random_genes.csv', na_values=' ', index_col='gene_id')

# df_cell_type_connection = pd.read_csv(RESULTS_PATH + r'cell_type_connection.csv', na_values=' ', index_col='cell_type')
# cell_type_connection = df_cell_type_connection.values.astype(np.float_)

max_rows = df.iloc[:,1:].apply(lambda x: x.sort_values(ascending=False).values, axis=1, result_type='broadcast').iloc[:,:4].mean(axis=1).values
df_norm = df.iloc[np.nonzero(max_rows)[0],1:].divide(max_rows[np.nonzero(max_rows)[0]], axis='rows')

list_cell_codes, list_cell_types = pd.factorize(df.iloc[:,0])

m0 = df_norm.values.astype(np.float_)
# m0_nan_0 = m0.copy()

# # create m0_weight with ones and zeros if not_missing/missing value
# m0_weight = np.where(np.isnan(m0), 0, 1)
# m0_nan_0[np.isnan(m0_nan_0)]=0
# df_norm.to_csv(RESULTS_PATH + r'\abis_915_norm.csv', sep=',', na_rep='.', index=True)

list_columns = df.columns[1:].to_list()
score_pref = ['9JD4', '925L', 'DZQV', 'G4YW']
n_scores = len(score_pref)
list_items = df.columns[1:].str[5:].to_list()[0:int((df.shape[1]-1)/n_scores)]

n_items = [len(list_items) for i in range(n_scores+1)]
Xs=[m0[:,i*n_items[0]:(i+1)*n_items[0]] for i in range(n_scores)]

# Check data
print(f'There are {len(Xs)} views.')
print(f'There are {Xs[0].shape[0]} observations')
print(f'The feature sizes are: {[X.shape[1] for X in Xs]}')
# Out:
# There are 4 views.
# There are 915 observations
# The feature sizes are: [16, 16, 16, 16]

# %%
Xs_norm = Xs.copy()
scaler = StandardScaler()
for i in range(len(Xs)):
    Xs_norm[i] = Xs[i] - np.mean(Xs[i], axis=0)
    Xs_norm[i] = scaler.fit_transform(Xs_norm[i])

# %%
gfa_cov = np.zeros(17)
for k in range(2,17):
    model = gfa_experiments(Xs_norm, K=k, Nrep=10, rotate=False, verbose=1)
    gfa_cov[k] = np.trace(model['covZ'])

for k in range(2,17):
    print(k, gfa_cov[k])
# Out:
# Run 1/10: 28 iterations with final cost -79133.627351
# Run 2/10: 23 iterations with final cost -79133.321350
# Run 3/10: 16 iterations with final cost -79133.830448
# Run 4/10: 20 iterations with final cost -79133.105362
# Run 5/10: 26 iterations with final cost -79133.329685
# Run 6/10: 23 iterations with final cost -79133.408659
# Run 7/10: 23 iterations with final cost -79133.481792
# Run 8/10: 24 iterations with final cost -79134.140336
# Run 9/10: 23 iterations with final cost -79134.045420
# Run 10/10: 17 iterations with final cost -79132.655500
# Run 1/10: 32 iterations with final cost -77513.596871
# Run 2/10: 30 iterations with final cost -77505.595932
# Run 3/10: 25 iterations with final cost -77495.436187
# Run 4/10: 27 iterations with final cost -77497.948565
# Run 5/10: 26 iterations with final cost -77499.112911
# Run 6/10: 27 iterations with final cost -77493.195845
# Run 7/10: 25 iterations with final cost -77496.050161
# Run 8/10: 25 iterations with final cost -77540.457009
# Run 9/10: 37 iterations with final cost -77514.254467
# Run 10/10: 25 iterations with final cost -77550.867540
# Run 1/10: 33 iterations with final cost -75709.644131
# Run 2/10: 26 iterations with final cost -75711.204962
# Run 3/10: 26 iterations with final cost -75711.235998
# Run 4/10: 25 iterations with final cost -75710.567401
# Run 5/10: 25 iterations with final cost -75711.314459
# Run 6/10: 44 iterations with final cost -75710.455504
# Run 7/10: 29 iterations with final cost -75710.496997
# Run 8/10: 27 iterations with final cost -75712.121180
# Run 9/10: 27 iterations with final cost -75710.253012
# Run 10/10: 25 iterations with final cost -75710.851655
# Run 1/10: 27 iterations with final cost -74027.583067
# Run 2/10: 27 iterations with final cost -74028.276789
# Run 3/10: 34 iterations with final cost -74026.962922
# Run 4/10: 33 iterations with final cost -74025.903755
# Run 5/10: 28 iterations with final cost -74027.528315
# Run 6/10: 29 iterations with final cost -74026.579656
# Run 7/10: 27 iterations with final cost -74028.000348
# Run 8/10: 30 iterations with final cost -74026.345601
# Run 9/10: 27 iterations with final cost -74027.365882
# Run 10/10: 27 iterations with final cost -74027.368407
# Run 1/10: 29 iterations with final cost -72487.362661
# Run 2/10: 32 iterations with final cost -72489.841912
# Run 3/10: 31 iterations with final cost -72489.225791
# Run 4/10: 31 iterations with final cost -72488.413621
# Run 5/10: 52 iterations with final cost -72489.335949
# Run 6/10: 31 iterations with final cost -72489.059457
# Run 7/10: 29 iterations with final cost -72487.360039
# Run 8/10: 38 iterations with final cost -72489.128497
# Run 9/10: 37 iterations with final cost -72488.239003
# Run 10/10: 51 iterations with final cost -72488.832360
# Run 1/10: 31 iterations with final cost -70845.745829
# Run 2/10: 71 iterations with final cost -70846.732188
# Run 3/10: 37 iterations with final cost -70846.160452
# Run 4/10: 32 iterations with final cost -70845.269671
# Run 5/10: 40 iterations with final cost -70846.772607
# Run 6/10: 60 iterations with final cost -70848.482012
# Run 7/10: 54 iterations with final cost -70846.519951
# Run 8/10: 32 iterations with final cost -70846.187451
# Run 9/10: 34 iterations with final cost -70845.270803
# Run 10/10: 32 iterations with final cost -70844.006296
# Run 1/10: 34 iterations with final cost -69010.620569
# Run 2/10: 34 iterations with final cost -69009.318643
# Run 3/10: 34 iterations with final cost -69012.154542
# Run 4/10: 40 iterations with final cost -69008.406950
# Run 5/10: 34 iterations with final cost -69010.121889
# Run 6/10: 34 iterations with final cost -69010.137533
# Run 7/10: 34 iterations with final cost -69009.928168
# Run 8/10: 34 iterations with final cost -69010.444206
# Run 9/10: 34 iterations with final cost -69010.083894
# Run 10/10: 34 iterations with final cost -69009.831346
# Run 1/10: 37 iterations with final cost -67286.941021
# Run 2/10: 37 iterations with final cost -67285.867151
# Run 3/10: 37 iterations with final cost -67286.768141
# Run 4/10: 37 iterations with final cost -67286.447249
# Run 5/10: 36 iterations with final cost -67287.371044
# Run 6/10: 36 iterations with final cost -67289.156804
# Run 7/10: 36 iterations with final cost -67288.566760
# Run 8/10: 36 iterations with final cost -67290.157376
# Run 9/10: 37 iterations with final cost -67285.881783
# Run 10/10: 37 iterations with final cost -67286.508978
# Run 1/10: 41 iterations with final cost -65849.410268
# Run 2/10: 41 iterations with final cost -65843.901034
# Run 3/10: 40 iterations with final cost -65845.307374
# Run 4/10: 40 iterations with final cost -65857.785155
# Run 5/10: 40 iterations with final cost -65863.185054
# Run 6/10: 40 iterations with final cost -65858.125543
# Run 7/10: 40 iterations with final cost -65857.853866
# Run 8/10: 40 iterations with final cost -65858.208232
# Run 9/10: 41 iterations with final cost -65852.845070
# Run 10/10: 40 iterations with final cost -65840.791721
# Run 1/10: 43 iterations with final cost -64093.442167
# Run 2/10: 44 iterations with final cost -64095.518125
# Run 3/10: 44 iterations with final cost -64089.678892
# Run 4/10: 44 iterations with final cost -64097.058567
# Run 5/10: 44 iterations with final cost -64090.141989
# Run 6/10: 45 iterations with final cost -64091.087084
# Run 7/10: 45 iterations with final cost -64091.831165
# Run 8/10: 44 iterations with final cost -64092.982727
# Run 9/10: 43 iterations with final cost -64093.247055
# Run 10/10: 58 iterations with final cost -64093.034465
# Run 1/10: 49 iterations with final cost -62236.703934
# Run 2/10: 48 iterations with final cost -62235.260811
# Run 3/10: 56 iterations with final cost -62237.967645
# Run 4/10: 48 iterations with final cost -62239.178022
# Run 5/10: 48 iterations with final cost -62237.928236
# Run 6/10: 69 iterations with final cost -62238.856855
# Run 7/10: 96 iterations with final cost -62241.889811
# Run 8/10: 50 iterations with final cost -62238.513633
# Run 9/10: 48 iterations with final cost -62237.542964
# Run 10/10: 52 iterations with final cost -62239.677541
# Run 1/10: 54 iterations with final cost -60018.523915
# Run 2/10: 54 iterations with final cost -60018.735026
# Run 3/10: 53 iterations with final cost -60022.210333
# Run 4/10: 53 iterations with final cost -60022.706013
# Run 5/10: 53 iterations with final cost -60023.648656
# Run 6/10: 53 iterations with final cost -60019.958242
# Run 7/10: 53 iterations with final cost -60019.839124
# Run 8/10: 53 iterations with final cost -60022.789413
# Run 9/10: 53 iterations with final cost -60021.871057
# Run 10/10: 52 iterations with final cost -60026.172941
# Run 1/10: 60 iterations with final cost -58051.724962
# Run 2/10: 59 iterations with final cost -58050.141786
# Run 3/10: 60 iterations with final cost -58050.284310
# Run 4/10: 59 iterations with final cost -58052.903692
# Run 5/10: 60 iterations with final cost -58051.755448
# Run 6/10: 59 iterations with final cost -58054.183808
# Run 7/10: 59 iterations with final cost -58053.262162
# Run 8/10: 60 iterations with final cost -58051.652224
# Run 9/10: 59 iterations with final cost -58056.502592
# Run 10/10: 60 iterations with final cost -58050.462085
# Run 1/10: 66 iterations with final cost -56188.295141
# Run 2/10: 66 iterations with final cost -56189.081257
# Run 3/10: 66 iterations with final cost -56188.873968
# Run 4/10: 67 iterations with final cost -56186.430837
# Run 5/10: 67 iterations with final cost -56184.196409
# Run 6/10: 66 iterations with final cost -56189.217537
# Run 7/10: 66 iterations with final cost -56187.309886
# Run 8/10: 67 iterations with final cost -56181.227384
# Run 9/10: 66 iterations with final cost -56189.386589
# Run 10/10: 67 iterations with final cost -56185.024603
# Run 1/10: 70 iterations with final cost -55849.103936
# Run 2/10: 70 iterations with final cost -55855.953329
# Run 3/10: 68 iterations with final cost -55861.775228
# Run 4/10: 70 iterations with final cost -55847.880293
# Run 5/10: 70 iterations with final cost -55853.659722
# Run 6/10: 68 iterations with final cost -55858.166473
# Run 7/10: 70 iterations with final cost -55849.960448
# Run 8/10: 70 iterations with final cost -55846.840813
# Run 9/10: 71 iterations with final cost -55845.252837
# Run 10/10: 70 iterations with final cost -55852.718339
# 2 0.23159680376213573
# 3 0.34331383306059915
# 4 0.4338863227188512
# 5 0.5216526273913719
# 6 0.609857040804352
# 7 0.6780515852038045
# 8 0.723185713857353
# 9 0.7705462739265636
# 10 0.8318415569464609
# 11 0.8575380392987341
# 12 0.8703369567718819
# 13 0.8501306985219168
# 14 0.8445466381368256
# 15 0.8347411103695592
# 16 1.0097974537975956

# %% [markdown]
# Figures

# %%
pca = PCA(n_components=16)

# Concatenate views then PCA for comparison
Xs_concat = Xs[0]
for X in Xs[1:]:
    Xs_concat = np.hstack((Xs_concat, X))
Xs_pca_reduced = pca.fit_transform(Xs_concat)


# Plot the scree plot
plt.plot (np.arange (1, pca.n_components_ + 1), pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.xlabel ('Principal Component')
plt.ylabel ('Variance Explained')
plt.title ('Scree Plot')
plt.grid ()
plt.show ()

# %%
# Plot the scree plot
plt.plot (np.arange(2,17), gfa_cov[2:17], 'o-', linewidth=2, color='blue')
plt.xlabel ('Principal Component')
plt.ylabel ('Variance Explained')
plt.title ('Scree Plot')
plt.grid ()
plt.show ()
