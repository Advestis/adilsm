# %%
from adnmtf import NMF, NTF
# from sklearn.decomposition import NMF
import pandas as pd
import numpy as np
from IPython.display import clear_output
import time
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import matplotlib.image as image
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import distinctipy
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

import sys
import networkx as nx
from sklearn.preprocessing import normalize
from sklearn import metrics

from mvlearn.datasets import load_UCImultifeature
from mvlearn.embed import MVMDS
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.cluster import KMeans
import umap
from scipy.spatial import distance_matrix
import hoggorm as ho
from sklearn.metrics.cluster import rand_score

import adilsm.adilsm as ilsm
import os

from sklearn.preprocessing import StandardScaler
from sklearn.metrics.cluster import rand_score
from mofapy2.run.entry_point import entry_point
from scipy.stats import trim_mean


RESULTS_PATH = '../results/'
DATA_PATH = '../data/'
# Out:
# adilsm version=0.0.13

# %% [markdown]
# Data prep

# %%
df = pd.read_csv(DATA_PATH + 'abis_915.csv', na_values=' ', index_col='gene_id')
# df = pd.read_csv(RESULTS_PATH + r'\abis_915_1000_random_genes.csv', na_values=' ', index_col='gene_id')

# df_cell_type_connection = pd.read_csv(RESULTS_PATH + r'cell_type_connection.csv', na_values=' ', index_col='cell_type')
# cell_type_connection = df_cell_type_connection.values.astype(np.float_)

max_rows = df.iloc[:,1:].apply(lambda x: x.sort_values(ascending=False).values, axis=1, result_type='broadcast').iloc[:,:4].mean(axis=1).values
df_norm = df.iloc[np.nonzero(max_rows)[0],1:].divide(max_rows[np.nonzero(max_rows)[0]], axis='rows')

list_cell_codes, list_cell_types = pd.factorize(df.iloc[:,0])

m0 = df_norm.values.astype(np.float_)
# m0_nan_0 = m0.copy()

# # create m0_weight with ones and zeros if not_missing/missing value
# m0_weight = np.where(np.isnan(m0), 0, 1)
# m0_nan_0[np.isnan(m0_nan_0)]=0
# df_norm.to_csv(RESULTS_PATH + r'\abis_915_norm.csv', sep=',', na_rep='.', index=True)

list_columns = df.columns[1:].to_list()
score_pref = ['9JD4', '925L', 'DZQV', 'G4YW']
n_scores = len(score_pref)
list_items = df.columns[1:].str[5:].to_list()[0:int((df.shape[1]-1)/n_scores)]

n_items = [len(list_items) for i in range(n_scores+1)]
Xs=[m0[:,i*n_items[0]:(i+1)*n_items[0]] for i in range(n_scores)]

# Check data
print(f'There are {len(Xs)} views.')
print(f'There are {Xs[0].shape[0]} observations')
print(f'The feature sizes are: {[X.shape[1] for X in Xs]}')
# Out:
# There are 4 views.
# There are 915 observations
# The feature sizes are: [16, 16, 16, 16]

# %%
Xs_norm = Xs.copy()
scaler = StandardScaler()
for i in range(len(Xs)):
    Xs_norm[i] = Xs[i] - np.mean(Xs[i], axis=0)
    Xs_norm[i] = scaler.fit_transform(Xs_norm[i])

# %%
total_variance = np.zeros(17)
for k in range(2,17):
    data_mat = [[None for g in range(1)] for m in range(4)]

    for m in range(4):
        data_mat[m][0] = Xs_norm[m]

    ent = entry_point()
    ent.set_data_matrix(data_mat, likelihoods = ["gaussian" for _ in range(4)])
    ent.set_model_options(
        factors = k, 
        spikeslab_weights = False, 
        ard_weights = True
    )
    ent.set_train_options(
        convergence_mode = "medium", 
        dropR2 = 0.001, 
        gpu_mode = False, 
        seed = 1
    )
    ent.build()
    ent.run()

    total_variance[k] = np.sum(ent.model.calculate_variance_explained())
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -180060.33
#
# Iteration 1: time=0.01, ELBO=-82808.81, deltaELBO=97251.517 (54.01051845%), Factors=1
# Iteration 2: time=0.01, ELBO=-81284.48, deltaELBO=1524.330 (0.84656651%), Factors=1
# Iteration 3: time=0.00, ELBO=-81074.24, deltaELBO=210.245 (0.11676381%), Factors=1
# Iteration 4: time=0.01, ELBO=-80994.47, deltaELBO=79.763 (0.04429780%), Factors=1
# Iteration 5: time=0.00, ELBO=-80950.31, deltaELBO=44.161 (0.02452584%), Factors=1
# Iteration 6: time=0.00, ELBO=-80920.83, deltaELBO=29.479 (0.01637199%), Factors=1
# Iteration 7: time=0.02, ELBO=-80897.48, deltaELBO=23.349 (0.01296705%), Factors=1
# Iteration 8: time=0.01, ELBO=-80875.66, deltaELBO=21.819 (0.01211769%), Factors=1
# Iteration 9: time=0.00, ELBO=-80852.09, deltaELBO=23.573 (0.01309169%), Factors=1
# Iteration 10: time=0.02, ELBO=-80823.69, deltaELBO=28.399 (0.01577220%), Factors=1
# Iteration 11: time=0.00, ELBO=-80787.06, deltaELBO=36.630 (0.02034302%), Factors=1
# Iteration 12: time=0.01, ELBO=-80738.34, deltaELBO=48.727 (0.02706138%), Factors=1
# Iteration 13: time=0.00, ELBO=-80673.57, deltaELBO=64.766 (0.03596904%), Factors=1
# Iteration 14: time=0.02, ELBO=-80589.68, deltaELBO=83.893 (0.04659147%), Factors=1
# Iteration 15: time=0.00, ELBO=-80486.00, deltaELBO=103.677 (0.05757896%), Factors=1
# Iteration 16: time=0.00, ELBO=-80368.21, deltaELBO=117.787 (0.06541527%), Factors=1
# Iteration 17: time=0.00, ELBO=-80253.96, deltaELBO=114.250 (0.06345122%), Factors=1
# Iteration 18: time=0.00, ELBO=-80166.37, deltaELBO=87.597 (0.04864844%), Factors=1
# Iteration 19: time=0.02, ELBO=-80113.64, deltaELBO=52.729 (0.02928390%), Factors=1
# Iteration 20: time=0.00, ELBO=-80086.70, deltaELBO=26.936 (0.01495962%), Factors=1
# Iteration 21: time=0.02, ELBO=-80073.85, deltaELBO=12.849 (0.00713593%), Factors=1
# Iteration 22: time=0.00, ELBO=-80067.76, deltaELBO=6.090 (0.00338242%), Factors=1
# Iteration 23: time=0.02, ELBO=-80064.78, deltaELBO=2.979 (0.00165418%), Factors=1
# Iteration 24: time=0.00, ELBO=-80063.24, deltaELBO=1.546 (0.00085833%), Factors=1
# Iteration 25: time=0.02, ELBO=-80062.37, deltaELBO=0.867 (0.00048170%), Factors=1
# Iteration 26: time=0.00, ELBO=-80061.84, deltaELBO=0.532 (0.00029524%), Factors=1
# Iteration 27: time=0.02, ELBO=-80061.48, deltaELBO=0.356 (0.00019786%), Factors=1
# Iteration 28: time=0.01, ELBO=-80061.22, deltaELBO=0.259 (0.00014406%), Factors=1
# Iteration 29: time=0.01, ELBO=-80061.02, deltaELBO=0.203 (0.00011254%), Factors=1
# Iteration 30: time=0.00, ELBO=-80060.85, deltaELBO=0.167 (0.00009290%), Factors=1
# Iteration 31: time=0.01, ELBO=-80060.71, deltaELBO=0.144 (0.00007982%), Factors=1
# Iteration 32: time=0.00, ELBO=-80060.58, deltaELBO=0.127 (0.00007051%), Factors=1
# Iteration 33: time=0.02, ELBO=-80060.47, deltaELBO=0.114 (0.00006343%), Factors=1
# Iteration 34: time=0.00, ELBO=-80060.36, deltaELBO=0.104 (0.00005775%), Factors=1
# Iteration 35: time=0.02, ELBO=-80060.27, deltaELBO=0.095 (0.00005298%), Factors=1
# Iteration 36: time=0.00, ELBO=-80060.18, deltaELBO=0.088 (0.00004885%), Factors=1
# Iteration 37: time=0.02, ELBO=-80060.10, deltaELBO=0.081 (0.00004518%), Factors=1
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -211701.49
#
# Iteration 1: time=0.01, ELBO=-82599.17, deltaELBO=129102.316 (60.98318740%), Factors=2
# Iteration 2: time=0.01, ELBO=-81320.30, deltaELBO=1278.877 (0.60409462%), Factors=2
# Iteration 3: time=0.01, ELBO=-81041.84, deltaELBO=278.454 (0.13153136%), Factors=2
# Iteration 4: time=0.00, ELBO=-80891.22, deltaELBO=150.627 (0.07115059%), Factors=2
# Iteration 5: time=0.02, ELBO=-80747.44, deltaELBO=143.776 (0.06791438%), Factors=2
# Iteration 6: time=0.00, ELBO=-80576.60, deltaELBO=170.844 (0.08070049%), Factors=2
# Iteration 7: time=0.02, ELBO=-80324.91, deltaELBO=251.689 (0.11888885%), Factors=2
# Iteration 8: time=0.02, ELBO=-79847.19, deltaELBO=477.712 (0.22565343%), Factors=2
# Iteration 9: time=0.01, ELBO=-79155.07, deltaELBO=692.120 (0.32693190%), Factors=2
# Iteration 10: time=0.00, ELBO=-78707.62, deltaELBO=447.454 (0.21136085%), Factors=2
# Iteration 11: time=0.02, ELBO=-78526.66, deltaELBO=180.966 (0.08548149%), Factors=2
# Iteration 12: time=0.00, ELBO=-78402.88, deltaELBO=123.776 (0.05846719%), Factors=2
# Iteration 13: time=0.01, ELBO=-78272.38, deltaELBO=130.499 (0.06164309%), Factors=2
# Iteration 14: time=0.01, ELBO=-78143.21, deltaELBO=129.167 (0.06101355%), Factors=2
# Iteration 15: time=0.00, ELBO=-78042.86, deltaELBO=100.358 (0.04740525%), Factors=2
# Iteration 16: time=0.02, ELBO=-77983.16, deltaELBO=59.696 (0.02819813%), Factors=2
# Iteration 17: time=0.01, ELBO=-77953.61, deltaELBO=29.554 (0.01396023%), Factors=2
# Iteration 18: time=0.01, ELBO=-77939.69, deltaELBO=13.913 (0.00657207%), Factors=2
# Iteration 19: time=0.01, ELBO=-77932.70, deltaELBO=6.990 (0.00330185%), Factors=2
# Iteration 20: time=0.05, ELBO=-77928.70, deltaELBO=4.001 (0.00189009%), Factors=2
# Iteration 21: time=0.02, ELBO=-77926.07, deltaELBO=2.632 (0.00124343%), Factors=2
# Iteration 22: time=0.01, ELBO=-77924.14, deltaELBO=1.926 (0.00090954%), Factors=2
# Iteration 23: time=0.01, ELBO=-77922.64, deltaELBO=1.503 (0.00071012%), Factors=2
# Iteration 24: time=0.01, ELBO=-77921.42, deltaELBO=1.217 (0.00057499%), Factors=2
# Iteration 25: time=0.02, ELBO=-77920.42, deltaELBO=1.006 (0.00047524%), Factors=2
# Iteration 26: time=0.02, ELBO=-77919.57, deltaELBO=0.842 (0.00039782%), Factors=2
# Iteration 27: time=0.01, ELBO=-77918.86, deltaELBO=0.711 (0.00033600%), Factors=2
# Iteration 28: time=0.01, ELBO=-77918.26, deltaELBO=0.605 (0.00028583%), Factors=2
# Iteration 29: time=0.00, ELBO=-77917.74, deltaELBO=0.518 (0.00024468%), Factors=2
# Iteration 30: time=0.02, ELBO=-77917.29, deltaELBO=0.446 (0.00021067%), Factors=2
# Iteration 31: time=0.02, ELBO=-77916.91, deltaELBO=0.386 (0.00018241%), Factors=2
# Iteration 32: time=0.00, ELBO=-77916.57, deltaELBO=0.336 (0.00015879%), Factors=2
# Iteration 33: time=0.01, ELBO=-77916.28, deltaELBO=0.294 (0.00013899%), Factors=2
# Iteration 34: time=0.01, ELBO=-77916.02, deltaELBO=0.259 (0.00012231%), Factors=2
# Iteration 35: time=0.00, ELBO=-77915.79, deltaELBO=0.229 (0.00010822%), Factors=2
# Iteration 36: time=0.02, ELBO=-77915.59, deltaELBO=0.204 (0.00009628%), Factors=2
# Iteration 37: time=0.01, ELBO=-77915.40, deltaELBO=0.182 (0.00008613%), Factors=2
# Iteration 38: time=0.00, ELBO=-77915.24, deltaELBO=0.164 (0.00007749%), Factors=2
# Iteration 39: time=0.02, ELBO=-77915.09, deltaELBO=0.148 (0.00007010%), Factors=2
# Iteration 40: time=0.00, ELBO=-77914.96, deltaELBO=0.135 (0.00006378%), Factors=2
# Iteration 41: time=0.01, ELBO=-77914.83, deltaELBO=0.124 (0.00005835%), Factors=2
# Iteration 42: time=0.01, ELBO=-77914.72, deltaELBO=0.114 (0.00005369%), Factors=2
# Iteration 43: time=0.01, ELBO=-77914.61, deltaELBO=0.105 (0.00004968%), Factors=2
# Iteration 44: time=0.00, ELBO=-77914.52, deltaELBO=0.098 (0.00004622%), Factors=2
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -246185.54
#
# Iteration 1: time=0.01, ELBO=-82064.64, deltaELBO=164120.903 (66.66553199%), Factors=3
# Iteration 2: time=0.01, ELBO=-80051.96, deltaELBO=2012.686 (0.81754824%), Factors=3
# Iteration 3: time=0.02, ELBO=-79577.71, deltaELBO=474.251 (0.19263965%), Factors=3
# Iteration 4: time=0.01, ELBO=-79249.40, deltaELBO=328.308 (0.13335805%), Factors=3
# Iteration 5: time=0.01, ELBO=-78767.53, deltaELBO=481.864 (0.19573194%), Factors=3
# Iteration 6: time=0.00, ELBO=-78001.16, deltaELBO=766.378 (0.31130100%), Factors=3
# Iteration 7: time=0.01, ELBO=-77332.79, deltaELBO=668.363 (0.27148732%), Factors=3
# Iteration 8: time=0.02, ELBO=-76988.97, deltaELBO=343.827 (0.13966171%), Factors=3
# Iteration 9: time=0.02, ELBO=-76740.25, deltaELBO=248.720 (0.10102960%), Factors=3
# Iteration 10: time=0.02, ELBO=-76482.49, deltaELBO=257.759 (0.10470116%), Factors=3
# Iteration 11: time=0.01, ELBO=-76245.11, deltaELBO=237.379 (0.09642274%), Factors=3
# Iteration 12: time=0.02, ELBO=-76050.49, deltaELBO=194.621 (0.07905443%), Factors=3
# Iteration 13: time=0.05, ELBO=-75911.40, deltaELBO=139.083 (0.05649539%), Factors=3
# Iteration 14: time=0.01, ELBO=-75832.30, deltaELBO=79.107 (0.03213303%), Factors=3
# Iteration 15: time=0.01, ELBO=-75795.39, deltaELBO=36.902 (0.01498932%), Factors=3
# Iteration 16: time=0.00, ELBO=-75779.08, deltaELBO=16.315 (0.00662693%), Factors=3
# Iteration 17: time=0.02, ELBO=-75771.13, deltaELBO=7.948 (0.00322827%), Factors=3
# Iteration 18: time=0.02, ELBO=-75766.53, deltaELBO=4.602 (0.00186931%), Factors=3
# Iteration 19: time=0.02, ELBO=-75763.41, deltaELBO=3.121 (0.00126755%), Factors=3
# Iteration 20: time=0.02, ELBO=-75761.07, deltaELBO=2.344 (0.00095209%), Factors=3
# Iteration 21: time=0.01, ELBO=-75759.20, deltaELBO=1.862 (0.00075635%), Factors=3
# Iteration 22: time=0.01, ELBO=-75757.68, deltaELBO=1.524 (0.00061916%), Factors=3
# Iteration 23: time=0.00, ELBO=-75756.41, deltaELBO=1.270 (0.00051570%), Factors=3
# Iteration 24: time=0.02, ELBO=-75755.34, deltaELBO=1.069 (0.00043433%), Factors=3
# Iteration 25: time=0.02, ELBO=-75754.43, deltaELBO=0.908 (0.00036873%), Factors=3
# Iteration 26: time=0.01, ELBO=-75753.66, deltaELBO=0.775 (0.00031499%), Factors=3
# Iteration 27: time=0.01, ELBO=-75752.99, deltaELBO=0.666 (0.00027048%), Factors=3
# Iteration 28: time=0.00, ELBO=-75752.42, deltaELBO=0.574 (0.00023331%), Factors=3
# Iteration 29: time=0.02, ELBO=-75751.92, deltaELBO=0.497 (0.00020208%), Factors=3
# Iteration 30: time=0.01, ELBO=-75751.49, deltaELBO=0.433 (0.00017571%), Factors=3
# Iteration 31: time=0.02, ELBO=-75751.11, deltaELBO=0.377 (0.00015333%), Factors=3
# Iteration 32: time=0.01, ELBO=-75750.78, deltaELBO=0.331 (0.00013428%), Factors=3
# Iteration 33: time=0.00, ELBO=-75750.49, deltaELBO=0.291 (0.00011801%), Factors=3
# Iteration 34: time=0.02, ELBO=-75750.23, deltaELBO=0.256 (0.00010407%), Factors=3
# Iteration 35: time=0.01, ELBO=-75750.01, deltaELBO=0.227 (0.00009210%), Factors=3
# Iteration 36: time=0.01, ELBO=-75749.80, deltaELBO=0.201 (0.00008179%), Factors=3
# Iteration 37: time=0.00, ELBO=-75749.63, deltaELBO=0.179 (0.00007289%), Factors=3
# Iteration 38: time=0.00, ELBO=-75749.46, deltaELBO=0.160 (0.00006519%), Factors=3
# Iteration 39: time=0.02, ELBO=-75749.32, deltaELBO=0.144 (0.00005853%), Factors=3
# Iteration 40: time=0.02, ELBO=-75749.19, deltaELBO=0.130 (0.00005274%), Factors=3
# Iteration 41: time=0.00, ELBO=-75749.07, deltaELBO=0.117 (0.00004771%), Factors=3
# Iteration 42: time=0.02, ELBO=-75748.97, deltaELBO=0.107 (0.00004332%), Factors=3
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -285543.94
#
# Iteration 1: time=0.02, ELBO=-80743.70, deltaELBO=204800.234 (71.72284484%), Factors=4
# Iteration 2: time=0.00, ELBO=-76978.08, deltaELBO=3765.626 (1.31875549%), Factors=4
# Iteration 3: time=0.02, ELBO=-76009.11, deltaELBO=968.970 (0.33934174%), Factors=4
# Iteration 4: time=0.02, ELBO=-75560.09, deltaELBO=449.015 (0.15724895%), Factors=4
# Iteration 5: time=0.02, ELBO=-75382.06, deltaELBO=178.034 (0.06234920%), Factors=4
# Iteration 6: time=0.01, ELBO=-75301.64, deltaELBO=80.419 (0.02816333%), Factors=4
# Iteration 7: time=0.00, ELBO=-75252.00, deltaELBO=49.637 (0.01738338%), Factors=4
# Iteration 8: time=0.02, ELBO=-75214.45, deltaELBO=37.555 (0.01315197%), Factors=4
# Iteration 9: time=0.02, ELBO=-75178.04, deltaELBO=36.405 (0.01274932%), Factors=4
# Iteration 10: time=0.02, ELBO=-75129.89, deltaELBO=48.153 (0.01686370%), Factors=4
# Iteration 11: time=0.00, ELBO=-75050.65, deltaELBO=79.235 (0.02774876%), Factors=4
# Iteration 12: time=0.02, ELBO=-74918.97, deltaELBO=131.685 (0.04611729%), Factors=4
# Iteration 13: time=0.02, ELBO=-74739.60, deltaELBO=179.373 (0.06281783%), Factors=4
# Iteration 14: time=0.02, ELBO=-74565.87, deltaELBO=173.723 (0.06083934%), Factors=4
# Iteration 15: time=0.00, ELBO=-74439.25, deltaELBO=126.624 (0.04434484%), Factors=4
# Iteration 16: time=0.02, ELBO=-74350.81, deltaELBO=88.435 (0.03097060%), Factors=4
# Iteration 17: time=0.01, ELBO=-74288.45, deltaELBO=62.360 (0.02183912%), Factors=4
# Iteration 18: time=0.02, ELBO=-74249.15, deltaELBO=39.299 (0.01376269%), Factors=4
# Iteration 19: time=0.02, ELBO=-74226.94, deltaELBO=22.217 (0.00778045%), Factors=4
# Iteration 20: time=0.00, ELBO=-74213.90, deltaELBO=13.035 (0.00456485%), Factors=4
# Iteration 21: time=0.03, ELBO=-74204.67, deltaELBO=9.238 (0.00323515%), Factors=4
# Iteration 22: time=0.00, ELBO=-74196.59, deltaELBO=8.073 (0.00282733%), Factors=4
# Iteration 23: time=0.02, ELBO=-74188.45, deltaELBO=8.138 (0.00284997%), Factors=4
# Iteration 24: time=0.02, ELBO=-74179.51, deltaELBO=8.943 (0.00313184%), Factors=4
# Iteration 25: time=0.02, ELBO=-74169.09, deltaELBO=10.423 (0.00365019%), Factors=4
# Iteration 26: time=0.00, ELBO=-74156.35, deltaELBO=12.734 (0.00445961%), Factors=4
# Iteration 27: time=0.00, ELBO=-74140.14, deltaELBO=16.211 (0.00567724%), Factors=4
# Iteration 28: time=0.02, ELBO=-74118.75, deltaELBO=21.393 (0.00749194%), Factors=4
# Iteration 29: time=0.06, ELBO=-74089.69, deltaELBO=29.060 (0.01017722%), Factors=4
# Iteration 30: time=0.03, ELBO=-74049.49, deltaELBO=40.201 (0.01407868%), Factors=4
# Iteration 31: time=0.05, ELBO=-73993.75, deltaELBO=55.740 (0.01952061%), Factors=4
# Iteration 32: time=0.02, ELBO=-73917.85, deltaELBO=75.897 (0.02657964%), Factors=4
# Iteration 33: time=0.02, ELBO=-73818.53, deltaELBO=99.320 (0.03478283%), Factors=4
# Iteration 34: time=0.01, ELBO=-73696.47, deltaELBO=122.065 (0.04274811%), Factors=4
# Iteration 35: time=0.01, ELBO=-73561.79, deltaELBO=134.682 (0.04716681%), Factors=4
# Iteration 36: time=0.02, ELBO=-73439.50, deltaELBO=122.283 (0.04282468%), Factors=4
# Iteration 37: time=0.02, ELBO=-73354.96, deltaELBO=84.538 (0.02960606%), Factors=4
# Iteration 38: time=0.01, ELBO=-73309.48, deltaELBO=45.488 (0.01593032%), Factors=4
# Iteration 39: time=0.02, ELBO=-73288.02, deltaELBO=21.456 (0.00751415%), Factors=4
# Iteration 40: time=0.01, ELBO=-73277.93, deltaELBO=10.091 (0.00353387%), Factors=4
# Iteration 41: time=0.01, ELBO=-73272.76, deltaELBO=5.166 (0.00180901%), Factors=4
# Iteration 42: time=0.02, ELBO=-73269.76, deltaELBO=3.000 (0.00105054%), Factors=4
# Iteration 43: time=0.02, ELBO=-73267.80, deltaELBO=1.967 (0.00068875%), Factors=4
# Iteration 44: time=0.02, ELBO=-73266.39, deltaELBO=1.410 (0.00049378%), Factors=4
# Iteration 45: time=0.02, ELBO=-73265.32, deltaELBO=1.070 (0.00037470%), Factors=4
# Iteration 46: time=0.02, ELBO=-73264.48, deltaELBO=0.840 (0.00029435%), Factors=4
# Iteration 47: time=0.02, ELBO=-73263.80, deltaELBO=0.675 (0.00023639%), Factors=4
# Iteration 48: time=0.01, ELBO=-73263.25, deltaELBO=0.551 (0.00019283%), Factors=4
# Iteration 49: time=0.02, ELBO=-73262.80, deltaELBO=0.455 (0.00015928%), Factors=4
# Iteration 50: time=0.02, ELBO=-73262.42, deltaELBO=0.380 (0.00013306%), Factors=4
# Iteration 51: time=0.03, ELBO=-73262.10, deltaELBO=0.321 (0.00011238%), Factors=4
# Iteration 52: time=0.00, ELBO=-73261.82, deltaELBO=0.274 (0.00009595%), Factors=4
# Iteration 53: time=0.02, ELBO=-73261.59, deltaELBO=0.237 (0.00008285%), Factors=4
# Iteration 54: time=0.03, ELBO=-73261.38, deltaELBO=0.207 (0.00007235%), Factors=4
# Iteration 55: time=0.02, ELBO=-73261.20, deltaELBO=0.182 (0.00006390%), Factors=4
# Iteration 56: time=0.02, ELBO=-73261.03, deltaELBO=0.163 (0.00005708%), Factors=4
# Iteration 57: time=0.02, ELBO=-73260.89, deltaELBO=0.147 (0.00005154%), Factors=4
# Iteration 58: time=0.02, ELBO=-73260.75, deltaELBO=0.134 (0.00004703%), Factors=4
# Iteration 59: time=0.01, ELBO=-73260.63, deltaELBO=0.124 (0.00004333%), Factors=4
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -325441.90
#
# Iteration 1: time=0.02, ELBO=-80473.38, deltaELBO=244968.520 (75.27258206%), Factors=5
# Iteration 2: time=0.02, ELBO=-75531.62, deltaELBO=4941.757 (1.51847599%), Factors=5
# Iteration 3: time=0.02, ELBO=-74265.08, deltaELBO=1266.541 (0.38917570%), Factors=5
# Iteration 4: time=0.02, ELBO=-73848.62, deltaELBO=416.462 (0.12796828%), Factors=5
# Iteration 5: time=0.02, ELBO=-73639.81, deltaELBO=208.811 (0.06416216%), Factors=5
# Iteration 6: time=0.02, ELBO=-73480.16, deltaELBO=159.647 (0.04905547%), Factors=5
# Iteration 7: time=0.03, ELBO=-73323.97, deltaELBO=156.193 (0.04799403%), Factors=5
# Iteration 8: time=0.02, ELBO=-73133.93, deltaELBO=190.037 (0.05839354%), Factors=5
# Iteration 9: time=0.02, ELBO=-72856.02, deltaELBO=277.915 (0.08539620%), Factors=5
# Iteration 10: time=0.02, ELBO=-72435.29, deltaELBO=420.730 (0.12927974%), Factors=5
# Iteration 11: time=0.02, ELBO=-71964.81, deltaELBO=470.480 (0.14456652%), Factors=5
# Iteration 12: time=0.02, ELBO=-71663.07, deltaELBO=301.740 (0.09271707%), Factors=5
# Iteration 13: time=0.02, ELBO=-71505.62, deltaELBO=157.444 (0.04837856%), Factors=5
# Iteration 14: time=0.02, ELBO=-71400.10, deltaELBO=105.521 (0.03242401%), Factors=5
# Iteration 15: time=0.02, ELBO=-71323.96, deltaELBO=76.141 (0.02339625%), Factors=5
# Iteration 16: time=0.02, ELBO=-71274.16, deltaELBO=49.802 (0.01530279%), Factors=5
# Iteration 17: time=0.02, ELBO=-71244.96, deltaELBO=29.193 (0.00897026%), Factors=5
# Iteration 18: time=0.02, ELBO=-71228.33, deltaELBO=16.633 (0.00511086%), Factors=5
# Iteration 19: time=0.02, ELBO=-71217.86, deltaELBO=10.469 (0.00321691%), Factors=5
# Iteration 20: time=0.02, ELBO=-71209.93, deltaELBO=7.935 (0.00243826%), Factors=5
# Iteration 21: time=0.02, ELBO=-71202.75, deltaELBO=7.175 (0.00220469%), Factors=5
# Iteration 22: time=0.02, ELBO=-71195.41, deltaELBO=7.337 (0.00225462%), Factors=5
# Iteration 23: time=0.02, ELBO=-71187.27, deltaELBO=8.140 (0.00250112%), Factors=5
# Iteration 24: time=0.02, ELBO=-71177.71, deltaELBO=9.565 (0.00293901%), Factors=5
# Iteration 25: time=0.01, ELBO=-71165.99, deltaELBO=11.724 (0.00360250%), Factors=5
# Iteration 26: time=0.01, ELBO=-71151.20, deltaELBO=14.788 (0.00454392%), Factors=5
# Iteration 27: time=0.01, ELBO=-71132.30, deltaELBO=18.900 (0.00580758%), Factors=5
# Iteration 28: time=0.02, ELBO=-71108.30, deltaELBO=24.000 (0.00737467%), Factors=5
# Iteration 29: time=0.02, ELBO=-71078.81, deltaELBO=29.491 (0.00906192%), Factors=5
# Iteration 30: time=0.02, ELBO=-71044.93, deltaELBO=33.878 (0.01040990%), Factors=5
# Iteration 31: time=0.02, ELBO=-71009.99, deltaELBO=34.935 (0.01073452%), Factors=5
# Iteration 32: time=0.01, ELBO=-70978.86, deltaELBO=31.130 (0.00956548%), Factors=5
# Iteration 33: time=0.02, ELBO=-70955.37, deltaELBO=23.490 (0.00721778%), Factors=5
# Iteration 34: time=0.01, ELBO=-70940.20, deltaELBO=15.176 (0.00466326%), Factors=5
# Iteration 35: time=0.02, ELBO=-70931.42, deltaELBO=8.780 (0.00269774%), Factors=5
# Iteration 36: time=0.02, ELBO=-70926.55, deltaELBO=4.870 (0.00149654%), Factors=5
# Iteration 37: time=0.02, ELBO=-70923.76, deltaELBO=2.787 (0.00085631%), Factors=5
# Iteration 38: time=0.02, ELBO=-70922.03, deltaELBO=1.731 (0.00053197%), Factors=5
# Iteration 39: time=0.02, ELBO=-70920.85, deltaELBO=1.183 (0.00036353%), Factors=5
# Iteration 40: time=0.03, ELBO=-70919.97, deltaELBO=0.875 (0.00026887%), Factors=5
# Iteration 41: time=0.02, ELBO=-70919.29, deltaELBO=0.684 (0.00021003%), Factors=5
# Iteration 42: time=0.02, ELBO=-70918.73, deltaELBO=0.553 (0.00016989%), Factors=5
# Iteration 43: time=0.02, ELBO=-70918.28, deltaELBO=0.457 (0.00014052%), Factors=5
# Iteration 44: time=0.02, ELBO=-70917.89, deltaELBO=0.384 (0.00011803%), Factors=5
# Iteration 45: time=0.01, ELBO=-70917.57, deltaELBO=0.326 (0.00010028%), Factors=5
# Iteration 46: time=0.02, ELBO=-70917.29, deltaELBO=0.280 (0.00008602%), Factors=5
# Iteration 47: time=0.02, ELBO=-70917.04, deltaELBO=0.242 (0.00007443%), Factors=5
# Iteration 48: time=0.01, ELBO=-70916.83, deltaELBO=0.211 (0.00006494%), Factors=5
# Iteration 49: time=0.02, ELBO=-70916.65, deltaELBO=0.186 (0.00005711%), Factors=5
# Iteration 50: time=0.03, ELBO=-70916.48, deltaELBO=0.165 (0.00005063%), Factors=5
# Iteration 51: time=0.01, ELBO=-70916.34, deltaELBO=0.147 (0.00004525%), Factors=5
# Iteration 52: time=0.02, ELBO=-70916.20, deltaELBO=0.133 (0.00004076%), Factors=5
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -360073.29
#
# Iteration 1: time=0.03, ELBO=-79742.48, deltaELBO=280330.809 (77.85381961%), Factors=6
# Iteration 2: time=0.02, ELBO=-73224.56, deltaELBO=6517.922 (1.81016541%), Factors=6
# Iteration 3: time=0.02, ELBO=-71327.33, deltaELBO=1897.225 (0.52689980%), Factors=6
# Iteration 4: time=0.02, ELBO=-70643.16, deltaELBO=684.172 (0.19000904%), Factors=6
# Iteration 5: time=0.02, ELBO=-70285.33, deltaELBO=357.827 (0.09937627%), Factors=6
# Iteration 6: time=0.02, ELBO=-70032.38, deltaELBO=252.949 (0.07024928%), Factors=6
# Iteration 7: time=0.01, ELBO=-69826.88, deltaELBO=205.508 (0.05707387%), Factors=6
# Iteration 8: time=0.03, ELBO=-69672.81, deltaELBO=154.062 (0.04278639%), Factors=6
# Iteration 9: time=0.02, ELBO=-69569.10, deltaELBO=103.716 (0.02880405%), Factors=6
# Iteration 10: time=0.02, ELBO=-69497.24, deltaELBO=71.858 (0.01995646%), Factors=6
# Iteration 11: time=0.02, ELBO=-69441.41, deltaELBO=55.828 (0.01550452%), Factors=6
# Iteration 12: time=0.02, ELBO=-69393.35, deltaELBO=48.059 (0.01334689%), Factors=6
# Iteration 13: time=0.02, ELBO=-69349.01, deltaELBO=44.346 (0.01231571%), Factors=6
# Iteration 14: time=0.02, ELBO=-69306.09, deltaELBO=42.914 (0.01191818%), Factors=6
# Iteration 15: time=0.02, ELBO=-69263.14, deltaELBO=42.956 (0.01192986%), Factors=6
# Iteration 16: time=0.02, ELBO=-69219.21, deltaELBO=43.930 (0.01220019%), Factors=6
# Iteration 17: time=0.02, ELBO=-69173.97, deltaELBO=45.238 (0.01256349%), Factors=6
# Iteration 18: time=0.02, ELBO=-69127.93, deltaELBO=46.046 (0.01278796%), Factors=6
# Iteration 19: time=0.02, ELBO=-69082.64, deltaELBO=45.283 (0.01257593%), Factors=6
# Iteration 20: time=0.02, ELBO=-69040.65, deltaELBO=41.993 (0.01166248%), Factors=6
# Iteration 21: time=0.06, ELBO=-69004.68, deltaELBO=35.971 (0.00998981%), Factors=6
# Iteration 22: time=0.03, ELBO=-68976.54, deltaELBO=28.138 (0.00781453%), Factors=6
# Iteration 23: time=0.02, ELBO=-68956.38, deltaELBO=20.165 (0.00560029%), Factors=6
# Iteration 24: time=0.03, ELBO=-68942.87, deltaELBO=13.506 (0.00375104%), Factors=6
# Iteration 25: time=0.03, ELBO=-68934.13, deltaELBO=8.744 (0.00242832%), Factors=6
# Iteration 26: time=0.02, ELBO=-68928.44, deltaELBO=5.686 (0.00157915%), Factors=6
# Iteration 27: time=0.02, ELBO=-68924.60, deltaELBO=3.837 (0.00106555%), Factors=6
# Iteration 28: time=0.02, ELBO=-68921.87, deltaELBO=2.734 (0.00075939%), Factors=6
# Iteration 29: time=0.03, ELBO=-68919.81, deltaELBO=2.063 (0.00057281%), Factors=6
# Iteration 30: time=0.02, ELBO=-68918.17, deltaELBO=1.634 (0.00045367%), Factors=6
# Iteration 31: time=0.02, ELBO=-68916.83, deltaELBO=1.343 (0.00037309%), Factors=6
# Iteration 32: time=0.03, ELBO=-68915.69, deltaELBO=1.136 (0.00031540%), Factors=6
# Iteration 33: time=0.02, ELBO=-68914.71, deltaELBO=0.980 (0.00027204%), Factors=6
# Iteration 34: time=0.03, ELBO=-68913.86, deltaELBO=0.858 (0.00023819%), Factors=6
# Iteration 35: time=0.02, ELBO=-68913.10, deltaELBO=0.760 (0.00021102%), Factors=6
# Iteration 36: time=0.03, ELBO=-68912.42, deltaELBO=0.680 (0.00018877%), Factors=6
# Iteration 37: time=0.02, ELBO=-68911.80, deltaELBO=0.613 (0.00017027%), Factors=6
# Iteration 38: time=0.03, ELBO=-68911.25, deltaELBO=0.557 (0.00015474%), Factors=6
# Iteration 39: time=0.02, ELBO=-68910.74, deltaELBO=0.510 (0.00014159%), Factors=6
# Iteration 40: time=0.03, ELBO=-68910.27, deltaELBO=0.469 (0.00013038%), Factors=6
# Iteration 41: time=0.02, ELBO=-68909.83, deltaELBO=0.435 (0.00012078%), Factors=6
# Iteration 42: time=0.01, ELBO=-68909.43, deltaELBO=0.405 (0.00011253%), Factors=6
# Iteration 43: time=0.02, ELBO=-68909.05, deltaELBO=0.380 (0.00010541%), Factors=6
# Iteration 44: time=0.02, ELBO=-68908.69, deltaELBO=0.357 (0.00009925%), Factors=6
# Iteration 45: time=0.04, ELBO=-68908.35, deltaELBO=0.338 (0.00009390%), Factors=6
# Iteration 46: time=0.02, ELBO=-68908.03, deltaELBO=0.321 (0.00008925%), Factors=6
# Iteration 47: time=0.03, ELBO=-68907.72, deltaELBO=0.307 (0.00008519%), Factors=6
# Iteration 48: time=0.01, ELBO=-68907.43, deltaELBO=0.294 (0.00008165%), Factors=6
# Iteration 49: time=0.02, ELBO=-68907.15, deltaELBO=0.283 (0.00007856%), Factors=6
# Iteration 50: time=0.02, ELBO=-68906.87, deltaELBO=0.273 (0.00007585%), Factors=6
# Iteration 51: time=0.01, ELBO=-68906.61, deltaELBO=0.265 (0.00007347%), Factors=6
# Iteration 52: time=0.02, ELBO=-68906.35, deltaELBO=0.257 (0.00007139%), Factors=6
# Iteration 53: time=0.03, ELBO=-68906.10, deltaELBO=0.250 (0.00006956%), Factors=6
# Iteration 54: time=0.02, ELBO=-68905.86, deltaELBO=0.245 (0.00006795%), Factors=6
# Iteration 55: time=0.02, ELBO=-68905.62, deltaELBO=0.240 (0.00006653%), Factors=6
# Iteration 56: time=0.02, ELBO=-68905.38, deltaELBO=0.235 (0.00006528%), Factors=6
# Iteration 57: time=0.02, ELBO=-68905.15, deltaELBO=0.231 (0.00006418%), Factors=6
# Iteration 58: time=0.03, ELBO=-68904.92, deltaELBO=0.228 (0.00006321%), Factors=6
# Iteration 59: time=0.02, ELBO=-68904.70, deltaELBO=0.224 (0.00006235%), Factors=6
# Iteration 60: time=0.02, ELBO=-68904.48, deltaELBO=0.222 (0.00006159%), Factors=6
# Iteration 61: time=0.02, ELBO=-68904.26, deltaELBO=0.219 (0.00006092%), Factors=6
# Iteration 62: time=0.02, ELBO=-68904.04, deltaELBO=0.217 (0.00006033%), Factors=6
# Iteration 63: time=0.02, ELBO=-68903.82, deltaELBO=0.215 (0.00005980%), Factors=6
# Iteration 64: time=0.02, ELBO=-68903.61, deltaELBO=0.214 (0.00005934%), Factors=6
# Iteration 65: time=0.03, ELBO=-68903.40, deltaELBO=0.212 (0.00005892%), Factors=6
# Iteration 66: time=0.02, ELBO=-68903.19, deltaELBO=0.211 (0.00005856%), Factors=6
# Iteration 67: time=0.02, ELBO=-68902.98, deltaELBO=0.210 (0.00005823%), Factors=6
# Iteration 68: time=0.02, ELBO=-68902.77, deltaELBO=0.209 (0.00005794%), Factors=6
# Iteration 69: time=0.01, ELBO=-68902.56, deltaELBO=0.208 (0.00005768%), Factors=6
# Iteration 70: time=0.02, ELBO=-68902.36, deltaELBO=0.207 (0.00005745%), Factors=6
# Iteration 71: time=0.01, ELBO=-68902.15, deltaELBO=0.206 (0.00005724%), Factors=6
# Iteration 72: time=0.03, ELBO=-68901.94, deltaELBO=0.205 (0.00005706%), Factors=6
# Iteration 73: time=0.02, ELBO=-68901.74, deltaELBO=0.205 (0.00005689%), Factors=6
# Iteration 74: time=0.02, ELBO=-68901.53, deltaELBO=0.204 (0.00005674%), Factors=6
# Iteration 75: time=0.01, ELBO=-68901.33, deltaELBO=0.204 (0.00005660%), Factors=6
# Iteration 76: time=0.03, ELBO=-68901.13, deltaELBO=0.203 (0.00005647%), Factors=6
# Iteration 77: time=0.02, ELBO=-68900.92, deltaELBO=0.203 (0.00005636%), Factors=6
# Iteration 78: time=0.02, ELBO=-68900.72, deltaELBO=0.203 (0.00005625%), Factors=6
# Iteration 79: time=0.03, ELBO=-68900.52, deltaELBO=0.202 (0.00005615%), Factors=6
# Iteration 80: time=0.03, ELBO=-68900.32, deltaELBO=0.202 (0.00005606%), Factors=6
# Iteration 81: time=0.02, ELBO=-68900.12, deltaELBO=0.202 (0.00005598%), Factors=6
# Iteration 82: time=0.02, ELBO=-68899.92, deltaELBO=0.201 (0.00005590%), Factors=6
# Iteration 83: time=0.02, ELBO=-68899.71, deltaELBO=0.201 (0.00005582%), Factors=6
# Iteration 84: time=0.01, ELBO=-68899.51, deltaELBO=0.201 (0.00005575%), Factors=6
# Iteration 85: time=0.02, ELBO=-68899.31, deltaELBO=0.200 (0.00005568%), Factors=6
# Iteration 86: time=0.02, ELBO=-68899.11, deltaELBO=0.200 (0.00005561%), Factors=6
# Iteration 87: time=0.00, ELBO=-68898.91, deltaELBO=0.200 (0.00005554%), Factors=6
# Iteration 88: time=0.02, ELBO=-68898.71, deltaELBO=0.200 (0.00005548%), Factors=6
# Iteration 89: time=0.01, ELBO=-68898.51, deltaELBO=0.200 (0.00005541%), Factors=6
# Iteration 90: time=0.03, ELBO=-68898.31, deltaELBO=0.199 (0.00005535%), Factors=6
# Iteration 91: time=0.02, ELBO=-68898.12, deltaELBO=0.199 (0.00005529%), Factors=6
# Iteration 92: time=0.02, ELBO=-68897.92, deltaELBO=0.199 (0.00005523%), Factors=6
# Iteration 93: time=0.00, ELBO=-68897.72, deltaELBO=0.199 (0.00005516%), Factors=6
# Iteration 94: time=0.02, ELBO=-68897.52, deltaELBO=0.198 (0.00005510%), Factors=6
# Iteration 95: time=0.03, ELBO=-68897.32, deltaELBO=0.198 (0.00005504%), Factors=6
# Iteration 96: time=0.02, ELBO=-68897.12, deltaELBO=0.198 (0.00005498%), Factors=6
# Iteration 97: time=0.02, ELBO=-68896.93, deltaELBO=0.198 (0.00005491%), Factors=6
# Iteration 98: time=0.02, ELBO=-68896.73, deltaELBO=0.197 (0.00005485%), Factors=6
# Iteration 99: time=0.02, ELBO=-68896.53, deltaELBO=0.197 (0.00005478%), Factors=6
# Iteration 100: time=0.01, ELBO=-68896.33, deltaELBO=0.197 (0.00005472%), Factors=6
# Iteration 101: time=0.03, ELBO=-68896.14, deltaELBO=0.197 (0.00005465%), Factors=6
# Iteration 102: time=0.02, ELBO=-68895.94, deltaELBO=0.197 (0.00005458%), Factors=6
# Iteration 103: time=0.06, ELBO=-68895.74, deltaELBO=0.196 (0.00005451%), Factors=6
# Iteration 104: time=0.02, ELBO=-68895.55, deltaELBO=0.196 (0.00005444%), Factors=6
# Iteration 105: time=0.03, ELBO=-68895.35, deltaELBO=0.196 (0.00005437%), Factors=6
# Iteration 106: time=0.02, ELBO=-68895.16, deltaELBO=0.195 (0.00005429%), Factors=6
# Iteration 107: time=0.03, ELBO=-68894.96, deltaELBO=0.195 (0.00005422%), Factors=6
# Iteration 108: time=0.02, ELBO=-68894.77, deltaELBO=0.195 (0.00005414%), Factors=6
# Iteration 109: time=0.02, ELBO=-68894.57, deltaELBO=0.195 (0.00005407%), Factors=6
# Iteration 110: time=0.01, ELBO=-68894.38, deltaELBO=0.194 (0.00005399%), Factors=6
# Iteration 111: time=0.02, ELBO=-68894.18, deltaELBO=0.194 (0.00005391%), Factors=6
# Iteration 112: time=0.03, ELBO=-68893.99, deltaELBO=0.194 (0.00005383%), Factors=6
# Iteration 113: time=0.02, ELBO=-68893.80, deltaELBO=0.194 (0.00005375%), Factors=6
# Iteration 114: time=0.02, ELBO=-68893.60, deltaELBO=0.193 (0.00005367%), Factors=6
# Iteration 115: time=0.02, ELBO=-68893.41, deltaELBO=0.193 (0.00005358%), Factors=6
# Iteration 116: time=0.02, ELBO=-68893.22, deltaELBO=0.193 (0.00005350%), Factors=6
# Iteration 117: time=0.02, ELBO=-68893.02, deltaELBO=0.192 (0.00005342%), Factors=6
# Iteration 118: time=0.02, ELBO=-68892.83, deltaELBO=0.192 (0.00005333%), Factors=6
# Iteration 119: time=0.02, ELBO=-68892.64, deltaELBO=0.192 (0.00005324%), Factors=6
# Iteration 120: time=0.02, ELBO=-68892.45, deltaELBO=0.191 (0.00005315%), Factors=6
# Iteration 121: time=0.02, ELBO=-68892.26, deltaELBO=0.191 (0.00005306%), Factors=6
# Iteration 122: time=0.02, ELBO=-68892.07, deltaELBO=0.191 (0.00005297%), Factors=6
# Iteration 123: time=0.02, ELBO=-68891.88, deltaELBO=0.190 (0.00005288%), Factors=6
# Iteration 124: time=0.02, ELBO=-68891.69, deltaELBO=0.190 (0.00005279%), Factors=6
# Iteration 125: time=0.02, ELBO=-68891.50, deltaELBO=0.190 (0.00005270%), Factors=6
# Iteration 126: time=0.02, ELBO=-68891.31, deltaELBO=0.189 (0.00005261%), Factors=6
# Iteration 127: time=0.02, ELBO=-68891.12, deltaELBO=0.189 (0.00005251%), Factors=6
# Iteration 128: time=0.02, ELBO=-68890.93, deltaELBO=0.189 (0.00005242%), Factors=6
# Iteration 129: time=0.02, ELBO=-68890.74, deltaELBO=0.188 (0.00005232%), Factors=6
# Iteration 130: time=0.02, ELBO=-68890.55, deltaELBO=0.188 (0.00005223%), Factors=6
# Iteration 131: time=0.02, ELBO=-68890.37, deltaELBO=0.188 (0.00005213%), Factors=6
# Iteration 132: time=0.03, ELBO=-68890.18, deltaELBO=0.187 (0.00005203%), Factors=6
# Iteration 133: time=0.02, ELBO=-68889.99, deltaELBO=0.187 (0.00005194%), Factors=6
# Iteration 134: time=0.02, ELBO=-68889.81, deltaELBO=0.187 (0.00005184%), Factors=6
# Iteration 135: time=0.02, ELBO=-68889.62, deltaELBO=0.186 (0.00005174%), Factors=6
# Iteration 136: time=0.03, ELBO=-68889.43, deltaELBO=0.186 (0.00005164%), Factors=6
# Iteration 137: time=0.02, ELBO=-68889.25, deltaELBO=0.186 (0.00005154%), Factors=6
# Iteration 138: time=0.02, ELBO=-68889.06, deltaELBO=0.185 (0.00005144%), Factors=6
# Iteration 139: time=0.02, ELBO=-68888.88, deltaELBO=0.185 (0.00005134%), Factors=6
# Iteration 140: time=0.02, ELBO=-68888.69, deltaELBO=0.185 (0.00005124%), Factors=6
# Iteration 141: time=0.02, ELBO=-68888.51, deltaELBO=0.184 (0.00005114%), Factors=6
# Iteration 142: time=0.03, ELBO=-68888.32, deltaELBO=0.184 (0.00005104%), Factors=6
# Iteration 143: time=0.02, ELBO=-68888.14, deltaELBO=0.183 (0.00005094%), Factors=6
# Iteration 144: time=0.02, ELBO=-68887.96, deltaELBO=0.183 (0.00005084%), Factors=6
# Iteration 145: time=0.02, ELBO=-68887.78, deltaELBO=0.183 (0.00005074%), Factors=6
# Iteration 146: time=0.02, ELBO=-68887.59, deltaELBO=0.182 (0.00005064%), Factors=6
# Iteration 147: time=0.02, ELBO=-68887.41, deltaELBO=0.182 (0.00005054%), Factors=6
# Iteration 148: time=0.02, ELBO=-68887.23, deltaELBO=0.182 (0.00005044%), Factors=6
# Iteration 149: time=0.02, ELBO=-68887.05, deltaELBO=0.181 (0.00005034%), Factors=6
# Iteration 150: time=0.02, ELBO=-68886.87, deltaELBO=0.181 (0.00005024%), Factors=6
# Iteration 151: time=0.02, ELBO=-68886.69, deltaELBO=0.181 (0.00005014%), Factors=6
# Iteration 152: time=0.02, ELBO=-68886.51, deltaELBO=0.180 (0.00005004%), Factors=6
# Iteration 153: time=0.02, ELBO=-68886.33, deltaELBO=0.180 (0.00004994%), Factors=6
# Iteration 154: time=0.02, ELBO=-68886.15, deltaELBO=0.179 (0.00004984%), Factors=6
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -395353.66
#
# Iteration 1: time=0.02, ELBO=-80148.56, deltaELBO=315205.101 (79.72737609%), Factors=7
# Iteration 2: time=0.03, ELBO=-73687.08, deltaELBO=6461.484 (1.63435532%), Factors=7
# Iteration 3: time=0.02, ELBO=-71326.64, deltaELBO=2360.438 (0.59704474%), Factors=7
# Iteration 4: time=0.07, ELBO=-70242.29, deltaELBO=1084.344 (0.27427198%), Factors=7
# Iteration 5: time=0.06, ELBO=-69524.49, deltaELBO=717.802 (0.18155949%), Factors=7
# Iteration 6: time=0.03, ELBO=-68937.65, deltaELBO=586.842 (0.14843474%), Factors=7
# Iteration 7: time=0.04, ELBO=-68453.84, deltaELBO=483.815 (0.12237515%), Factors=7
# Iteration 8: time=0.03, ELBO=-68103.21, deltaELBO=350.628 (0.08868709%), Factors=7
# Iteration 9: time=0.02, ELBO=-67889.92, deltaELBO=213.284 (0.05394773%), Factors=7
# Iteration 10: time=0.02, ELBO=-67770.58, deltaELBO=119.339 (0.03018545%), Factors=7
# Iteration 11: time=0.03, ELBO=-67693.27, deltaELBO=77.313 (0.01955528%), Factors=7
# Iteration 12: time=0.03, ELBO=-67628.96, deltaELBO=64.317 (0.01626815%), Factors=7
# Iteration 13: time=0.02, ELBO=-67567.54, deltaELBO=61.414 (0.01553398%), Factors=7
# Iteration 14: time=0.03, ELBO=-67508.28, deltaELBO=59.259 (0.01498896%), Factors=7
# Iteration 15: time=0.02, ELBO=-67453.34, deltaELBO=54.944 (0.01389734%), Factors=7
# Iteration 16: time=0.02, ELBO=-67401.73, deltaELBO=51.612 (0.01305463%), Factors=7
# Iteration 17: time=0.02, ELBO=-67346.01, deltaELBO=55.720 (0.01409369%), Factors=7
# Iteration 18: time=0.02, ELBO=-67275.16, deltaELBO=70.842 (0.01791867%), Factors=7
# Iteration 19: time=0.02, ELBO=-67183.31, deltaELBO=91.851 (0.02323251%), Factors=7
# Iteration 20: time=0.03, ELBO=-67081.64, deltaELBO=101.676 (0.02571781%), Factors=7
# Iteration 21: time=0.02, ELBO=-66997.29, deltaELBO=84.347 (0.02133445%), Factors=7
# Iteration 22: time=0.01, ELBO=-66945.84, deltaELBO=51.448 (0.01301322%), Factors=7
# Iteration 23: time=0.02, ELBO=-66919.33, deltaELBO=26.517 (0.00670704%), Factors=7
# Iteration 24: time=0.02, ELBO=-66904.86, deltaELBO=14.465 (0.00365871%), Factors=7
# Iteration 25: time=0.02, ELBO=-66895.25, deltaELBO=9.607 (0.00243010%), Factors=7
# Iteration 26: time=0.03, ELBO=-66887.66, deltaELBO=7.589 (0.00191953%), Factors=7
# ...
# Iteration 63: time=0.03, ELBO=-55782.19, deltaELBO=0.657 (0.00010680%), Factors=13
# Iteration 64: time=0.02, ELBO=-55781.54, deltaELBO=0.644 (0.00010470%), Factors=13
# Iteration 65: time=0.03, ELBO=-55780.91, deltaELBO=0.632 (0.00010273%), Factors=13
# Iteration 66: time=0.02, ELBO=-55780.29, deltaELBO=0.621 (0.00010089%), Factors=13
# Iteration 67: time=0.03, ELBO=-55779.68, deltaELBO=0.610 (0.00009915%), Factors=13
# Iteration 68: time=0.02, ELBO=-55779.08, deltaELBO=0.600 (0.00009752%), Factors=13
# Iteration 69: time=0.03, ELBO=-55778.49, deltaELBO=0.591 (0.00009598%), Factors=13
# Iteration 70: time=0.02, ELBO=-55777.91, deltaELBO=0.582 (0.00009453%), Factors=13
# Iteration 71: time=0.03, ELBO=-55777.34, deltaELBO=0.573 (0.00009315%), Factors=13
# Iteration 72: time=0.02, ELBO=-55776.77, deltaELBO=0.565 (0.00009185%), Factors=13
# Iteration 73: time=0.03, ELBO=-55776.21, deltaELBO=0.558 (0.00009061%), Factors=13
# Iteration 74: time=0.02, ELBO=-55775.66, deltaELBO=0.550 (0.00008943%), Factors=13
# Iteration 75: time=0.02, ELBO=-55775.12, deltaELBO=0.543 (0.00008831%), Factors=13
# Iteration 76: time=0.02, ELBO=-55774.58, deltaELBO=0.537 (0.00008724%), Factors=13
# Iteration 77: time=0.06, ELBO=-55774.05, deltaELBO=0.530 (0.00008621%), Factors=13
# Iteration 78: time=0.06, ELBO=-55773.53, deltaELBO=0.524 (0.00008523%), Factors=13
# Iteration 79: time=0.03, ELBO=-55773.01, deltaELBO=0.519 (0.00008429%), Factors=13
# Iteration 80: time=0.03, ELBO=-55772.50, deltaELBO=0.513 (0.00008339%), Factors=13
# Iteration 81: time=0.02, ELBO=-55771.99, deltaELBO=0.508 (0.00008253%), Factors=13
# Iteration 82: time=0.03, ELBO=-55771.49, deltaELBO=0.503 (0.00008169%), Factors=13
# Iteration 83: time=0.03, ELBO=-55770.99, deltaELBO=0.498 (0.00008089%), Factors=13
# Iteration 84: time=0.03, ELBO=-55770.49, deltaELBO=0.493 (0.00008011%), Factors=13
# Iteration 85: time=0.02, ELBO=-55770.01, deltaELBO=0.488 (0.00007936%), Factors=13
# Iteration 86: time=0.03, ELBO=-55769.52, deltaELBO=0.484 (0.00007864%), Factors=13
# Iteration 87: time=0.03, ELBO=-55769.04, deltaELBO=0.480 (0.00007793%), Factors=13
# Iteration 88: time=0.03, ELBO=-55768.57, deltaELBO=0.475 (0.00007725%), Factors=13
# Iteration 89: time=0.02, ELBO=-55768.10, deltaELBO=0.471 (0.00007659%), Factors=13
# Iteration 90: time=0.03, ELBO=-55767.63, deltaELBO=0.467 (0.00007595%), Factors=13
# Iteration 91: time=0.02, ELBO=-55767.17, deltaELBO=0.463 (0.00007533%), Factors=13
# Iteration 92: time=0.02, ELBO=-55766.71, deltaELBO=0.460 (0.00007472%), Factors=13
# Iteration 93: time=0.03, ELBO=-55766.25, deltaELBO=0.456 (0.00007413%), Factors=13
# Iteration 94: time=0.03, ELBO=-55765.80, deltaELBO=0.453 (0.00007355%), Factors=13
# Iteration 95: time=0.02, ELBO=-55765.35, deltaELBO=0.449 (0.00007299%), Factors=13
# Iteration 96: time=0.03, ELBO=-55764.90, deltaELBO=0.446 (0.00007244%), Factors=13
# Iteration 97: time=0.02, ELBO=-55764.46, deltaELBO=0.442 (0.00007190%), Factors=13
# Iteration 98: time=0.03, ELBO=-55764.02, deltaELBO=0.439 (0.00007137%), Factors=13
# Iteration 99: time=0.03, ELBO=-55763.58, deltaELBO=0.436 (0.00007086%), Factors=13
# Iteration 100: time=0.02, ELBO=-55763.15, deltaELBO=0.433 (0.00007035%), Factors=13
# Iteration 101: time=0.03, ELBO=-55762.72, deltaELBO=0.430 (0.00006986%), Factors=13
# Iteration 102: time=0.02, ELBO=-55762.30, deltaELBO=0.427 (0.00006938%), Factors=13
# Iteration 103: time=0.02, ELBO=-55761.87, deltaELBO=0.424 (0.00006890%), Factors=13
# Iteration 104: time=0.02, ELBO=-55761.45, deltaELBO=0.421 (0.00006844%), Factors=13
# Iteration 105: time=0.03, ELBO=-55761.03, deltaELBO=0.418 (0.00006798%), Factors=13
# Iteration 106: time=0.02, ELBO=-55760.62, deltaELBO=0.416 (0.00006753%), Factors=13
# Iteration 107: time=0.02, ELBO=-55760.20, deltaELBO=0.413 (0.00006709%), Factors=13
# Iteration 108: time=0.02, ELBO=-55759.79, deltaELBO=0.410 (0.00006665%), Factors=13
# Iteration 109: time=0.03, ELBO=-55759.39, deltaELBO=0.407 (0.00006622%), Factors=13
# Iteration 110: time=0.02, ELBO=-55758.98, deltaELBO=0.405 (0.00006580%), Factors=13
# Iteration 111: time=0.03, ELBO=-55758.58, deltaELBO=0.402 (0.00006539%), Factors=13
# Iteration 112: time=0.02, ELBO=-55758.18, deltaELBO=0.400 (0.00006498%), Factors=13
# Iteration 113: time=0.03, ELBO=-55757.78, deltaELBO=0.397 (0.00006458%), Factors=13
# Iteration 114: time=0.02, ELBO=-55757.39, deltaELBO=0.395 (0.00006418%), Factors=13
# Iteration 115: time=0.03, ELBO=-55756.99, deltaELBO=0.393 (0.00006379%), Factors=13
# Iteration 116: time=0.02, ELBO=-55756.60, deltaELBO=0.390 (0.00006340%), Factors=13
# Iteration 117: time=0.02, ELBO=-55756.22, deltaELBO=0.388 (0.00006302%), Factors=13
# Iteration 118: time=0.03, ELBO=-55755.83, deltaELBO=0.385 (0.00006265%), Factors=13
# Iteration 119: time=0.02, ELBO=-55755.45, deltaELBO=0.383 (0.00006228%), Factors=13
# Iteration 120: time=0.03, ELBO=-55755.07, deltaELBO=0.381 (0.00006191%), Factors=13
# Iteration 121: time=0.02, ELBO=-55754.69, deltaELBO=0.379 (0.00006155%), Factors=13
# Iteration 122: time=0.03, ELBO=-55754.31, deltaELBO=0.377 (0.00006119%), Factors=13
# Iteration 123: time=0.02, ELBO=-55753.94, deltaELBO=0.374 (0.00006084%), Factors=13
# Iteration 124: time=0.02, ELBO=-55753.56, deltaELBO=0.372 (0.00006049%), Factors=13
# Iteration 125: time=0.06, ELBO=-55753.19, deltaELBO=0.370 (0.00006015%), Factors=13
# Iteration 126: time=0.04, ELBO=-55752.83, deltaELBO=0.368 (0.00005981%), Factors=13
# Iteration 127: time=0.03, ELBO=-55752.46, deltaELBO=0.366 (0.00005947%), Factors=13
# Iteration 128: time=0.03, ELBO=-55752.10, deltaELBO=0.364 (0.00005914%), Factors=13
# Iteration 129: time=0.02, ELBO=-55751.74, deltaELBO=0.362 (0.00005881%), Factors=13
# Iteration 130: time=0.03, ELBO=-55751.38, deltaELBO=0.360 (0.00005848%), Factors=13
# Iteration 131: time=0.03, ELBO=-55751.02, deltaELBO=0.358 (0.00005816%), Factors=13
# Iteration 132: time=0.03, ELBO=-55750.66, deltaELBO=0.356 (0.00005784%), Factors=13
# Iteration 133: time=0.03, ELBO=-55750.31, deltaELBO=0.354 (0.00005753%), Factors=13
# Iteration 134: time=0.02, ELBO=-55749.96, deltaELBO=0.352 (0.00005721%), Factors=13
# Iteration 135: time=0.03, ELBO=-55749.61, deltaELBO=0.350 (0.00005690%), Factors=13
# Iteration 136: time=0.03, ELBO=-55749.26, deltaELBO=0.348 (0.00005660%), Factors=13
# Iteration 137: time=0.03, ELBO=-55748.91, deltaELBO=0.346 (0.00005629%), Factors=13
# Iteration 138: time=0.03, ELBO=-55748.57, deltaELBO=0.345 (0.00005599%), Factors=13
# Iteration 139: time=0.03, ELBO=-55748.22, deltaELBO=0.343 (0.00005570%), Factors=13
# Iteration 140: time=0.02, ELBO=-55747.88, deltaELBO=0.341 (0.00005540%), Factors=13
# Iteration 141: time=0.04, ELBO=-55747.54, deltaELBO=0.339 (0.00005511%), Factors=13
# Iteration 142: time=0.04, ELBO=-55747.21, deltaELBO=0.337 (0.00005482%), Factors=13
# Iteration 143: time=0.04, ELBO=-55746.87, deltaELBO=0.336 (0.00005453%), Factors=13
# Iteration 144: time=0.03, ELBO=-55746.54, deltaELBO=0.334 (0.00005425%), Factors=13
# Iteration 145: time=0.03, ELBO=-55746.20, deltaELBO=0.332 (0.00005397%), Factors=13
# Iteration 146: time=0.04, ELBO=-55745.87, deltaELBO=0.330 (0.00005369%), Factors=13
# Iteration 147: time=0.03, ELBO=-55745.55, deltaELBO=0.329 (0.00005341%), Factors=13
# Iteration 148: time=0.03, ELBO=-55745.22, deltaELBO=0.327 (0.00005314%), Factors=13
# Iteration 149: time=0.03, ELBO=-55744.89, deltaELBO=0.325 (0.00005287%), Factors=13
# Iteration 150: time=0.03, ELBO=-55744.57, deltaELBO=0.324 (0.00005260%), Factors=13
# Iteration 151: time=0.02, ELBO=-55744.25, deltaELBO=0.322 (0.00005233%), Factors=13
# Iteration 152: time=0.03, ELBO=-55743.93, deltaELBO=0.320 (0.00005206%), Factors=13
# Iteration 153: time=0.03, ELBO=-55743.61, deltaELBO=0.319 (0.00005180%), Factors=13
# Iteration 154: time=0.03, ELBO=-55743.29, deltaELBO=0.317 (0.00005154%), Factors=13
# Iteration 155: time=0.03, ELBO=-55742.98, deltaELBO=0.316 (0.00005128%), Factors=13
# Iteration 156: time=0.03, ELBO=-55742.66, deltaELBO=0.314 (0.00005102%), Factors=13
# Iteration 157: time=0.03, ELBO=-55742.35, deltaELBO=0.312 (0.00005077%), Factors=13
# Iteration 158: time=0.03, ELBO=-55742.04, deltaELBO=0.311 (0.00005052%), Factors=13
# Iteration 159: time=0.03, ELBO=-55741.73, deltaELBO=0.309 (0.00005027%), Factors=13
# Iteration 160: time=0.03, ELBO=-55741.42, deltaELBO=0.308 (0.00005002%), Factors=13
# Iteration 161: time=0.01, ELBO=-55741.12, deltaELBO=0.306 (0.00004977%), Factors=13
# Iteration 162: time=0.04, ELBO=-55740.81, deltaELBO=0.305 (0.00004953%), Factors=13
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################
#
#
#
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# View names not provided, using default naming convention:
# - view1, view2, ..., viewM
#
# Features names not provided, using default naming convention:
# - feature1_view1, featureD_viewM
#
# Groups names not provided, using default naming convention:
# - group1, group2, ..., groupG
#
# Samples names not provided, using default naming convention:
# - sample1_group1, sample2_group1, sample1_group2, ..., sampleN_groupG
#
# Successfully loaded view='view0' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view1' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view2' group='group0' with N=915 samples and D=16 features...
# Successfully loaded view='view3' group='group0' with N=915 samples and D=16 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: False
# Likelihoods:
# - View 0 (view0): gaussian
# - View 1 (view1): gaussian
# - View 2 (view2): gaussian
# - View 3 (view3): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################
#
#
# ELBO before training: -645535.19
#
# Iteration 1: time=0.03, ELBO=-80045.18, deltaELBO=565490.011 (87.60018376%), Factors=15
# Iteration 2: time=0.07, ELBO=-69744.16, deltaELBO=10301.020 (1.59573328%), Factors=14
# Iteration 3: time=0.05, ELBO=-63151.18, deltaELBO=6592.979 (1.02131987%), Factors=13
# Iteration 4: time=0.03, ELBO=-59310.89, deltaELBO=3840.287 (0.59489976%), Factors=13
# Iteration 5: time=0.03, ELBO=-57762.93, deltaELBO=1547.965 (0.23979556%), Factors=13
# Iteration 6: time=0.03, ELBO=-57255.89, deltaELBO=507.036 (0.07854501%), Factors=13
# Iteration 7: time=0.03, ELBO=-57035.37, deltaELBO=220.523 (0.03416126%), Factors=13
# Iteration 8: time=0.03, ELBO=-56898.02, deltaELBO=137.347 (0.02127652%), Factors=13
# Iteration 9: time=0.03, ELBO=-56796.95, deltaELBO=101.070 (0.01565670%), Factors=13
# Iteration 10: time=0.03, ELBO=-56715.73, deltaELBO=81.225 (0.01258264%), Factors=13
# Iteration 11: time=0.03, ELBO=-56645.48, deltaELBO=70.243 (0.01088131%), Factors=13
# Iteration 12: time=0.03, ELBO=-56579.38, deltaELBO=66.100 (0.01023960%), Factors=13
# Iteration 13: time=0.03, ELBO=-56510.27, deltaELBO=69.110 (0.01070590%), Factors=13
# Iteration 14: time=0.03, ELBO=-56429.20, deltaELBO=81.077 (0.01255961%), Factors=13
# Iteration 15: time=0.03, ELBO=-56325.68, deltaELBO=103.519 (0.01603613%), Factors=13
# Iteration 16: time=0.02, ELBO=-56194.75, deltaELBO=130.929 (0.02028222%), Factors=13
# Iteration 17: time=0.02, ELBO=-56054.23, deltaELBO=140.517 (0.02176748%), Factors=13
# Iteration 18: time=0.03, ELBO=-55944.33, deltaELBO=109.897 (0.01702414%), Factors=13
# Iteration 19: time=0.02, ELBO=-55882.59, deltaELBO=61.748 (0.00956535%), Factors=13
# Iteration 20: time=0.03, ELBO=-55852.20, deltaELBO=30.389 (0.00470760%), Factors=13
# Iteration 21: time=0.03, ELBO=-55834.88, deltaELBO=17.320 (0.00268311%), Factors=13
# Iteration 22: time=0.03, ELBO=-55822.52, deltaELBO=12.356 (0.00191406%), Factors=13
# Iteration 23: time=0.03, ELBO=-55812.59, deltaELBO=9.931 (0.00153845%), Factors=13
# Iteration 24: time=0.03, ELBO=-55804.25, deltaELBO=8.337 (0.00129154%), Factors=13
# Iteration 25: time=0.03, ELBO=-55797.12, deltaELBO=7.128 (0.00110424%), Factors=13
# Iteration 26: time=0.03, ELBO=-55790.96, deltaELBO=6.162 (0.00095455%), Factors=13
# Iteration 27: time=0.03, ELBO=-55785.59, deltaELBO=5.371 (0.00083209%), Factors=13
# Iteration 28: time=0.02, ELBO=-55780.88, deltaELBO=4.715 (0.00073043%), Factors=13
# Iteration 29: time=0.03, ELBO=-55776.71, deltaELBO=4.164 (0.00064505%), Factors=13
# Iteration 30: time=0.03, ELBO=-55773.01, deltaELBO=3.697 (0.00057268%), Factors=13
# Iteration 31: time=0.03, ELBO=-55769.72, deltaELBO=3.298 (0.00051082%), Factors=13
# Iteration 32: time=0.03, ELBO=-55766.76, deltaELBO=2.954 (0.00045758%), Factors=13
# Iteration 33: time=0.03, ELBO=-55764.11, deltaELBO=2.656 (0.00041146%), Factors=13
# Iteration 34: time=0.02, ELBO=-55761.71, deltaELBO=2.397 (0.00037130%), Factors=13
# Iteration 35: time=0.03, ELBO=-55759.54, deltaELBO=2.170 (0.00033615%), Factors=13
# Iteration 36: time=0.03, ELBO=-55757.57, deltaELBO=1.971 (0.00030525%), Factors=13
# Iteration 37: time=0.02, ELBO=-55755.77, deltaELBO=1.794 (0.00027798%), Factors=13
# Iteration 38: time=0.03, ELBO=-55754.14, deltaELBO=1.639 (0.00025384%), Factors=13
# Iteration 39: time=0.03, ELBO=-55752.64, deltaELBO=1.500 (0.00023238%), Factors=13
# Iteration 40: time=0.02, ELBO=-55751.26, deltaELBO=1.377 (0.00021326%), Factors=13
# Iteration 41: time=0.03, ELBO=-55749.99, deltaELBO=1.266 (0.00019618%), Factors=13
# Iteration 42: time=0.01, ELBO=-55748.83, deltaELBO=1.168 (0.00018089%), Factors=13
# Iteration 43: time=0.03, ELBO=-55747.75, deltaELBO=1.079 (0.00016716%), Factors=13
# Iteration 44: time=0.03, ELBO=-55746.75, deltaELBO=0.999 (0.00015481%), Factors=13
# Iteration 45: time=0.03, ELBO=-55745.82, deltaELBO=0.927 (0.00014368%), Factors=13
# Iteration 46: time=0.02, ELBO=-55744.96, deltaELBO=0.863 (0.00013363%), Factors=13
# Iteration 47: time=0.03, ELBO=-55744.15, deltaELBO=0.804 (0.00012455%), Factors=13
# Iteration 48: time=0.02, ELBO=-55743.40, deltaELBO=0.751 (0.00011632%), Factors=13
# Iteration 49: time=0.03, ELBO=-55742.70, deltaELBO=0.703 (0.00010886%), Factors=13
# Iteration 50: time=0.02, ELBO=-55742.04, deltaELBO=0.659 (0.00010208%), Factors=13
# Iteration 51: time=0.03, ELBO=-55741.42, deltaELBO=0.619 (0.00009592%), Factors=13
# Iteration 52: time=0.03, ELBO=-55740.84, deltaELBO=0.583 (0.00009031%), Factors=13
# Iteration 53: time=0.02, ELBO=-55740.29, deltaELBO=0.550 (0.00008519%), Factors=13
# Iteration 54: time=0.03, ELBO=-55739.77, deltaELBO=0.520 (0.00008053%), Factors=13
# Iteration 55: time=0.02, ELBO=-55739.28, deltaELBO=0.492 (0.00007626%), Factors=13
# Iteration 56: time=0.09, ELBO=-55738.81, deltaELBO=0.467 (0.00007236%), Factors=13
# Iteration 57: time=0.03, ELBO=-55738.36, deltaELBO=0.444 (0.00006879%), Factors=13
# Iteration 58: time=0.03, ELBO=-55737.94, deltaELBO=0.423 (0.00006552%), Factors=13
# Iteration 59: time=0.03, ELBO=-55737.54, deltaELBO=0.404 (0.00006252%), Factors=13
# Iteration 60: time=0.03, ELBO=-55737.15, deltaELBO=0.386 (0.00005976%), Factors=13
# Iteration 61: time=0.03, ELBO=-55736.78, deltaELBO=0.369 (0.00005723%), Factors=13
# Iteration 62: time=0.03, ELBO=-55736.43, deltaELBO=0.354 (0.00005490%), Factors=13
# Iteration 63: time=0.02, ELBO=-55736.09, deltaELBO=0.341 (0.00005275%), Factors=13
# Iteration 64: time=0.03, ELBO=-55735.76, deltaELBO=0.328 (0.00005077%), Factors=13
# Iteration 65: time=0.03, ELBO=-55735.44, deltaELBO=0.316 (0.00004895%), Factors=13
# Iteration 66: time=0.03, ELBO=-55735.14, deltaELBO=0.305 (0.00004727%), Factors=13
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################

# %% [markdown]
# Figures

# %%
# Plot the scree plot
plt.plot (np.arange(2,17), total_variance[2:17], 'o-', linewidth=2, color='blue')
plt.xlabel ('Principal Component')
plt.ylabel ('Variance Explained')
plt.title ('Scree Plot')
plt.grid ()
plt.show ()
